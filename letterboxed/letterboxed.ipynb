# %%
# get list of english words
# words must be 3 to 9 characters long and have a vowel
dictionary = 'words_alpha.txt'
# dictionary ='/usr/share/dict/words'
with open(dictionary) as f:
    words = f.read().splitlines()

words = [w for w in words if len(w) >= 3 and len(w) <= 9 and any(v in w for v in 'aeiouy')]
print(len(words))
# Out:
# 201741

# %%
# puzzle = 'enrtblaoipxs'
puzzle = 'uxofatnhecdr'

# %%
# find words that are possible to make in the puzzle

words_valid = []
for w in words:
    valid = True
    idx_last = (puzzle.find(w[0]) // 3) + 1
    if not idx_last:
        continue
    for c in w[1:]:
        idx = (puzzle.find(c) // 3) + 1
        if idx == idx_last or not idx:
            valid = False
            break
        idx_last = idx
    if valid:
        words_valid.append(w)
print(len(words_valid))
# Out:
# 2068

# %%
# valid pairs have last and first letters matching 
valid_pairs = [(w1,w2) for w2 in words_valid for w1 in words_valid if w2[0] == w1[-1]] 
two_word_solutions = [(w1,w2) for w1, w2 in valid_pairs if len(set(w1+w2)) == len(puzzle)]
print(len(valid_pairs))
print(len(two_word_solutions))
two_word_solutions
# Out:
# 377217
# 7
# [('rotunda', 'axfetch'),
#  ('uncoaxed', 'dearthfu'),
#  ('furnace', 'exhorted'),
#  ('axfetch', 'honduran'),
#  ('axfetch', 'hondurean'),
#  ('defunct', 'thorax'),
#  ('dearthfu', 'uncoaxed')]

# %%
# valid triples have last and first letters matching 
valid_triples = [(w1,w2,w3) for w3 in words_valid for w1,w2 in valid_pairs if w3[0] == w2[-1]]
print(len(valid_triples))
# Out:
# 69316128

# %%
three_word_solutions = [(w1,w2,w3) for w1,w2,w3 in valid_triples if len(set(w1+w2+w3)) == len(puzzle)]
print(len(three_word_solutions))
three_word_solutions
# Out:
# 39695
# [('fondue', 'externa', 'acanth'),
#  ('fondue', 'extra', 'acanth'),
#  ('fondue', 'externa', 'acantha'),
#  ('fondue', 'extra', 'acantha'),
#  ('confute', 'externa', 'acanthad'),
#  ('foeture', 'externa', 'acanthad'),
#  ('fondue', 'externa', 'acanthad'),
#  ('fronture', 'externa', 'acanthad'),
#  ('furore', 'externa', 'acanthad'),
#  ('confute', 'extra', 'acanthad'),
#  ('foeture', 'extra', 'acanthad'),
#  ('fondue', 'extra', 'acanthad'),
#  ('fronture', 'extra', 'acanthad'),
#  ('furore', 'extra', 'acanthad'),
#  ('fondue', 'externa', 'acanthon'),
#  ('fondue', 'extra', 'acanthon'),
#  ('fondue', 'externa', 'ach'),
#  ('fondue', 'extra', 'ach'),
#  ('fondue', 'externa', 'achaean'),
#  ('fondue', 'extra', 'achaean'),
#  ('fondue', 'externa', 'achar'),
#  ('fondue', 'extra', 'achar'),
#  ('fondue', 'externa', 'achor'),
#  ('fondue', 'extra', 'achor'),
#  ('fondue', 'externa', 'achter'),
#  ('fondue', 'extra', 'achter'),
#  ('fondue', 'externa', 'achuete'),
#  ('fronde', 'externa', 'achuete'),
#  ('fondue', 'extra', 'achuete'),
#  ('fronde', 'extra', 'achuete'),
#  ('axfetch', 'hornada', 'achuete'),
#  ('axfetch', 'haraucana', 'acnode'),
#  ('axfetch', 'hura', 'acnode'),
#  ('axfetch', 'hornada', 'actu'),
#  ('axfetch', 'honda', 'acture'),
#  ('axfetch', 'hornada', 'acture'),
#  ('axfetch', 'hornada', 'acuan'),
#  ('axfetch', 'haraucana', 'acuductor'),
#  ('axfetch', 'honda', 'acuductor'),
#  ('axfetch', 'honora', 'acuductor'),
#  ('axfetch', 'hornada', 'acuductor'),
#  ('axfetch', 'hornada', 'acute'),
#  ('axfetch', 'honda', 'acuter'),
#  ('axfetch', 'hornada', 'acuter'),
#  ('axfetch', 'honora', 'adaunt'),
#  ('axfetch', 'hora', 'adaunt'),
#  ('axfetch', 'hornada', 'adaunt'),
#  ('axfetch', 'haraucana', 'adeona'),
#  ('axfetch', 'hura', 'adeona'),
#  ('exhorted', 'daurna', 'adfected'),
#  ('hoaxed', 'daurna', 'adfected'),
#  ('uncoaxed', 'dharana', 'adfected'),
#  ('uncoaxed', 'dharna', 'adfected'),
#  ('uncoaxed', 'dhaura', 'adfected'),
#  ('coaxed', 'dhurna', 'adfected'),
#  ('coexerted', 'dhurna', 'adfected'),
#  ('exhorted', 'dhurna', 'adfected'),
#  ('extorted', 'dhurna', 'adfected'),
#  ('hoaxed', 'dhurna', 'adfected'),
#  ('uncoaxed', 'dhurna', 'adfected'),
#  ('exhance', 'eudora', 'adfected'),
#  ('cohue', 'externa', 'adfected'),
#  ('hodure', 'externa', 'adfected'),
#  ('exhorter', 'redunca', 'adfected'),
#  ('hoaxer', 'redunca', 'adfected'),
#  ('excur', 'rhonda', 'adfected'),
#  ('executer', 'rhonda', 'adfected'),
#  ('executor', 'rhonda', 'adfected'),
#  ('extruder', 'rhonda', 'adfected'),
#  ('axer', 'rohuna', 'adfected'),
#  ('coaxer', 'rohuna', 'adfected'),
#  ('dexter', 'rohuna', 'adfected'),
#  ('dextrer', 'rohuna', 'adfected'),
#  ('exacter', 'rohuna', 'adfected'),
#  ('exactor', 'rohuna', 'adfected'),
#  ('excur', 'rohuna', 'adfected'),
#  ('executer', 'rohuna', 'adfected'),
#  ('executor', 'rohuna', 'adfected'),
#  ('exhorter', 'rohuna', 'adfected'),
#  ('exr', 'rohuna', 'adfected'),
#  ('exter', 'rohuna', 'adfected'),
#  ('extorter', 'rohuna', 'adfected'),
#  ('extractor', 'rohuna', 'adfected'),
#  ('extruder', 'rohuna', 'adfected'),
#  ('hoaxer', 'rohuna', 'adfected'),
#  ('exhorter', 'rotunda', 'adfected'),
#  ('hoaxer', 'rotunda', 'adfected'),
#  ('exhorter', 'ruana', 'adfected'),
#  ('hoaxer', 'ruana', 'adfected'),
#  ('exhort', 'tecuna', 'adfected'),
#  ('exeunt', 'trocha', 'adfected'),
#  ('context', 'trucha', 'adfected'),
#  ('exhort', 'tucana', 'adfected'),
#  ('exhort', 'tucandera', 'adfected'),
#  ('exhort', 'tucuna', 'adfected'),
#  ('exhort', 'tuna', 'adfected'),
#  ('exhort', 'tunca', 'adfected'),
#  ('confute', 'externa', 'adhara'),
#  ('confute', 'extra', 'adhara'),
#  ('confute', 'externa', 'adhort'),
#  ('fracture', 'externa', 'adhort'),
#  ('fructure', 'externa', 'adhort'),
#  ('fucaceae', 'externa', 'adhort'),
#  ('furnace', 'externa', 'adhort'),
#  ('confute', 'extra', 'adhort'),
#  ('furnace', 'extra', 'adhort'),
#  ('xref', 'furacana', 'adhort'),
#  ('axfetch', 'haraucana', 'adhort'),
#  ('axfetch', 'haraucana', 'ado'),
#  ('axfetch', 'haraucana', 'adod'),
#  ('axfetch', 'haraucana', 'adon'),
#  ('axfetch', 'hura', 'adon'),
#  ('axfetch', 'haraucana', 'ador'),
#  ('axfetch', 'haraucana', 'adorant'),
#  ('axfetch', 'huaca', 'adorant'),
#  ('axfetch', 'hura', 'adorant'),
#  ('axfetch', 'haraucana', 'adore'),
#  ('axfetch', 'haraucana', 'adored'),
#  ('axfetch', 'haraucana', 'adorer'),
#  ('axfetch', 'haraucana', 'adorn'),
#  ('axfetch', 'huaca', 'adorn'),
#  ('axfetch', 'hura', 'adorn'),
#  ('axfetch', 'haraucana', 'adorno'),
#  ('axfetch', 'huaca', 'adorno'),
#  ('axfetch', 'hura', 'adorno'),
#  ('axfetch', 'honora', 'aduana'),
#  ('axfetch', 'hora', 'aduana'),
#  ('axfetch', 'hornada', 'aduana'),
#  ('axfetch', 'honora', 'adunc'),
#  ('axfetch', 'hora', 'adunc'),
#  ('axfetch', 'hornada', 'adunc'),
#  ('axfetch', 'honda', 'adure'),
#  ('axfetch', 'honora', 'adure'),
#  ('axfetch', 'hornada', 'adure'),
#  ('axfetch', 'haraucana', 'aeroduct'),
#  ('axfetch', 'honda', 'aeroduct'),
#  ('axfetch', 'honora', 'aeroduct'),
#  ('axfetch', 'hornada', 'aeroduct'),
#  ('axfetch', 'hadada', 'aeronaut'),
#  ('axfetch', 'honda', 'aeronaut'),
#  ('axfetch', 'hornada', 'aeronaut'),
#  ('fondue', 'externa', 'ahaunch'),
#  ('fronde', 'externa', 'ahaunch'),
#  ('fondue', 'extra', 'ahaunch'),
#  ('fronde', 'extra', 'ahaunch'),
#  ('axfetch', 'hornada', 'ahaunch'),
#  ('axfetch', 'hornada', 'ahu'),
#  ('fondue', 'externa', 'ahuaca'),
#  ('fronde', 'externa', 'ahuaca'),
#  ('fondue', 'extra', 'ahuaca'),
#  ('fronde', 'extra', 'ahuaca'),
#  ('axfetch', 'hornada', 'ahuaca'),
#  ('axfetch', 'hornada', 'ahunt'),
#  ('axfetch', 'honda', 'ahura'),
#  ('axfetch', 'hornada', 'ahura'),
#  ('fondue', 'externa', 'anacanth'),
#  ('fondue', 'extra', 'anacanth'),
#  ('fondue', 'externa', 'anachoret'),
#  ('fondue', 'extra', 'anachoret'),
#  ('axfetch', 'haraucana', 'anaconda'),
#  ('axfetch', 'hura', 'anaconda'),
#  ('axfetch', 'hornada', 'anahau'),
#  ('axfetch', 'honda', 'anaunter'),
#  ('axfetch', 'hornada', 'anaunter'),
#  ('unfronted', 'dacha', 'anax'),
#  ('confuted', 'dharana', 'anax'),
#  ('confuted', 'dharna', 'anax'),
#  ('confected', 'dhaura', 'anax'),
#  ('conferted', 'dhaura', 'anax'),
#  ('confuted', 'dhaura', 'anax'),
#  ('confected', 'dhurna', 'anax'),
#  ('conferted', 'dhurna', 'anax'),
#  ('confuted', 'dhurna', 'anax'),
#  ('underfo', 'ochotona', 'anax'),
#  ('confuter', 'rhoda', 'anax'),
#  ('confuter', 'rhodora', 'anax'),
#  ('confuter', 'rhonda', 'anax'),
#  ('defecter', 'rohuna', 'anax'),
#  ('defector', 'rohuna', 'anax'),
#  ('chaufer', 'rotonda', 'anax'),
#  ('chaufer', 'rotunda', 'anax'),
#  ('forthcut', 'teda', 'anax'),
#  ('forthcut', 'todea', 'anax'),
#  ('feucht', 'tornada', 'anax'),
#  ('defunct', 'trocha', 'anax'),
#  ('forthcut', 'tucandera', 'anax'),
#  ('fondue', 'externa', 'ancha'),
#  ('fondue', 'extra', 'ancha'),
#  ('fondue', 'externa', 'anchor'),
#  ('fondue', 'extra', 'anchor'),
#  ('confute', 'externa', 'anchored'),
#  ('feture', 'externa', 'anchored'),
#  ('feute', 'externa', 'anchored'),
#  ('foeture', 'externa', 'anchored'),
#  ('fondue', 'externa', 'anchored'),
#  ('fracture', 'externa', 'anchored'),
#  ('fronture', 'externa', 'anchored'),
#  ('fructure', 'externa', 'anchored'),
#  ('fucaceae', 'externa', 'anchored'),
#  ('fuerte', 'externa', 'anchored'),
#  ('furnace', 'externa', 'anchored'),
#  ('furore', 'externa', 'anchored'),
#  ('fute', 'externa', 'anchored'),
#  ('future', 'externa', 'anchored'),
#  ('refute', 'externa', 'anchored'),
#  ('unrufe', 'externa', 'anchored'),
#  ('confute', 'extra', 'anchored'),
#  ('feture', 'extra', 'anchored'),
#  ('feute', 'extra', 'anchored'),
#  ('foeture', 'extra', 'anchored'),
#  ('fondue', 'extra', 'anchored'),
#  ('fracture', 'extra', 'anchored'),
#  ('fronture', 'extra', 'anchored'),
#  ('fructure', 'extra', 'anchored'),
#  ('fucaceae', 'extra', 'anchored'),
#  ('fuerte', 'extra', 'anchored'),
#  ('furnace', 'extra', 'anchored'),
#  ('furore', 'extra', 'anchored'),
#  ('fute', 'extra', 'anchored'),
#  ('future', 'extra', 'anchored'),
#  ('refute', 'extra', 'anchored'),
#  ('unrufe', 'extra', 'anchored'),
#  ('axfetch', 'haraucana', 'anchored'),
#  ('axfetch', 'huaca', 'anchored'),
#  ('axfetch', 'hura', 'anchored'),
#  ('fondue', 'externa', 'anchorer'),
#  ('fondue', 'extra', 'anchorer'),
#  ('fondue', 'externa', 'anchoret'),
#  ('fondue', 'extra', 'anchoret'),
#  ('axfetch', 'haraucana', 'ancodont'),
#  ('axfetch', 'hura', 'ancodont'),
#  ('axfetch', 'haraucana', 'anconad'),
#  ('axfetch', 'hura', 'anconad'),
#  ('axfetch', 'honda', 'anderun'),
#  ('axfetch', 'honora', 'anderun'),
#  ('axfetch', 'hora', 'anderun'),
#  ('axfetch', 'hornada', 'anderun'),
#  ('axfetch', 'hotcha', 'anderun'),
#  ('confute', 'externa', 'andhra'),
#  ('confute', 'extra', 'andhra'),
#  ('axfetch', 'haraucana', 'andor'),
#  ('axfetch', 'huaca', 'andor'),
#  ('axfetch', 'hura', 'andor'),
#  ('uncoaxed', 'dacha', 'anfract'),
#  ('exhorted', 'daurna', 'anfract'),
#  ('hoaxed', 'daurna', 'anfract'),
#  ('uncoaxed', 'dha', 'anfract'),
#  ('uncoaxed', 'dharana', 'anfract'),
#  ('uncoaxed', 'dharna', 'anfract'),
#  ('coaxed', 'dhaura', 'anfract'),
#  ('coexerted', 'dhaura', 'anfract'),
#  ('exhorted', 'dhaura', 'anfract'),
#  ('extorted', 'dhaura', 'anfract'),
#  ('hoaxed', 'dhaura', 'anfract'),
#  ('uncoaxed', 'dhaura', 'anfract'),
#  ('coaxed', 'dhurna', 'anfract'),
#  ('coexerted', 'dhurna', 'anfract'),
#  ('exhorted', 'dhurna', 'anfract'),
#  ('extorted', 'dhurna', 'anfract'),
#  ('hoaxed', 'dhurna', 'anfract'),
#  ('uncoaxed', 'dhurna', 'anfract'),
#  ('exhorted', 'dura', 'anfract'),
#  ('hoaxed', 'dura', 'anfract'),
#  ('exhorted', 'dutra', 'anfract'),
#  ('hoaxed', 'dutra', 'anfract'),
#  ('exhance', 'eudora', 'anfract'),
#  ('hodure', 'externa', 'anfract'),
#  ('hodure', 'extra', 'anfract'),
#  ('exhorter', 'redunca', 'anfract'),
#  ('hoaxer', 'redunca', 'anfract'),
#  ('excur', 'rhoda', 'anfract'),
#  ('executer', 'rhoda', 'anfract'),
#  ('executor', 'rhoda', 'anfract'),
#  ('extruder', 'rhoda', 'anfract'),
#  ('excur', 'rhodora', 'anfract'),
#  ('executer', 'rhodora', 'anfract'),
#  ('executor', 'rhodora', 'anfract'),
#  ('extruder', 'rhodora', 'anfract'),
#  ('excur', 'rhonda', 'anfract'),
#  ('executer', 'rhonda', 'anfract'),
#  ('executor', 'rhonda', 'anfract'),
#  ('extruder', 'rhonda', 'anfract'),
#  ('dexter', 'rohuna', 'anfract'),
#  ('dextrer', 'rohuna', 'anfract'),
#  ('extruder', 'rohuna', 'anfract'),
#  ('exhorter', 'rotunda', 'anfract'),
#  ('hoaxer', 'rotunda', 'anfract'),
#  ('exhorter', 'rudera', 'anfract'),
#  ('hoaxer', 'rudera', 'anfract'),
#  ('exhort', 'tucandera', 'anfract'),
#  ('axfetch', 'haraucana', 'anode'),
#  ('axfetch', 'hura', 'anode'),
#  ('axfetch', 'haraucana', 'anodon'),
#  ('axfetch', 'hura', 'anodon'),
#  ('axfetch', 'haraucana', 'anonad'),
#  ('axfetch', 'hura', 'anonad'),
#  ('axfetch', 'hadada', 'antecornu'),
#  ('axfetch', 'honda', 'antecornu'),
#  ('axfetch', 'hornada', 'antecornu'),
#  ('axfetch', 'haraucana', 'antedon'),
#  ('axfetch', 'hura', 'antedon'),
#  ('furacana', 'adeona', 'anthrax'),
#  ('fedora', 'ahuaca', 'anthrax'),
#  ('fedora', 'arecuna', 'anthrax'),
#  ('fedora', 'auca', 'anthrax'),
#  ('confuted', 'dacha', 'anthrax'),
#  ('nonfecund', 'dacha', 'anthrax'),
#  ('nonfunded', 'dacha', 'anthrax'),
#  ('unfronted', 'dacha', 'anthrax'),
#  ('confuted', 'dada', 'anthrax'),
#  ('nonfecund', 'dada', 'anthrax'),
#  ('confuted', 'dana', 'anthrax'),
#  ('nonfecund', 'dana', 'anthrax'),
#  ('confuted', 'danda', 'anthrax'),
#  ('nonfecund', 'danda', 'anthrax'),
#  ('confected', 'daurna', 'anthrax'),
#  ('confed', 'daurna', 'anthrax'),
#  ('conferted', 'daurna', 'anthrax'),
#  ('confuted', 'daurna', 'anthrax'),
#  ('cornfed', 'daurna', 'anthrax'),
#  ('nonfecund', 'daurna', 'anthrax'),
#  ('confuted', 'dea', 'anthrax'),
#  ('nonfecund', 'dea', 'anthrax'),
#  ('confuted', 'deda', 'anthrax'),
#  ('nonfecund', 'deda', 'anthrax'),
#  ('confuted', 'deodara', 'anthrax'),
#  ('fecund', 'deodara', 'anthrax'),
#  ('fractured', 'deodara', 'anthrax'),
#  ('fructed', 'deodara', 'anthrax'),
#  ('furnaced', 'deodara', 'anthrax'),
#  ('nonfecund', 'deodara', 'anthrax'),
#  ('unfecund', 'deodara', 'anthrax'),
#  ('unfructed', 'deodara', 'anthrax'),
#  ('confuted', 'dertra', 'anthrax'),
#  ('nonfecund', 'dertra', 'anthrax'),
#  ('confuted', 'dha', 'anthrax'),
#  ('nonfecund', 'dha', 'anthrax'),
#  ('confuted', 'dharana', 'anthrax'),
#  ('nonfecund', 'dharana', 'anthrax'),
#  ('confuted', 'dharna', 'anthrax'),
#  ('nonfecund', 'dharna', 'anthrax'),
#  ('confected', 'dhaura', 'anthrax'),
#  ('confed', 'dhaura', 'anthrax'),
#  ('conferted', 'dhaura', 'anthrax'),
#  ('confuted', 'dhaura', 'anthrax'),
#  ('cornfed', 'dhaura', 'anthrax'),
#  ('nonfecund', 'dhaura', 'anthrax'),
#  ('confected', 'dhurna', 'anthrax'),
#  ('confed', 'dhurna', 'anthrax'),
#  ('conferted', 'dhurna', 'anthrax'),
#  ('confuted', 'dhurna', 'anthrax'),
#  ('cornfed', 'dhurna', 'anthrax'),
#  ('nonfecund', 'dhurna', 'anthrax'),
#  ('confuted', 'doa', 'anthrax'),
#  ('fecund', 'doa', 'anthrax'),
#  ('fractured', 'doa', 'anthrax'),
#  ('fructed', 'doa', 'anthrax'),
#  ('furnaced', 'doa', 'anthrax'),
#  ('nonfecund', 'doa', 'anthrax'),
#  ('unfecund', 'doa', 'anthrax'),
#  ('unfructed', 'doa', 'anthrax'),
#  ('confuted', 'dodona', 'anthrax'),
#  ('fecund', 'dodona', 'anthrax'),
#  ('fractured', 'dodona', 'anthrax'),
#  ('fructed', 'dodona', 'anthrax'),
#  ('furnaced', 'dodona', 'anthrax'),
#  ('nonfecund', 'dodona', 'anthrax'),
#  ('unfecund', 'dodona', 'anthrax'),
#  ('unfructed', 'dodona', 'anthrax'),
#  ('confuted', 'dodonaea', 'anthrax'),
#  ('fecund', 'dodonaea', 'anthrax'),
#  ('fractured', 'dodonaea', 'anthrax'),
#  ('fructed', 'dodonaea', 'anthrax'),
#  ('furnaced', 'dodonaea', 'anthrax'),
#  ('nonfecund', 'dodonaea', 'anthrax'),
#  ('unfecund', 'dodonaea', 'anthrax'),
#  ('unfructed', 'dodonaea', 'anthrax'),
#  ('confuted', 'dona', 'anthrax'),
#  ('fecund', 'dona', 'anthrax'),
#  ('fractured', 'dona', 'anthrax'),
#  ('fructed', 'dona', 'anthrax'),
#  ('furnaced', 'dona', 'anthrax'),
#  ('nonfecund', 'dona', 'anthrax'),
#  ('unfecund', 'dona', 'anthrax'),
#  ('unfructed', 'dona', 'anthrax'),
#  ('confuted', 'dora', 'anthrax'),
#  ('fecund', 'dora', 'anthrax'),
#  ('fractured', 'dora', 'anthrax'),
#  ('fructed', 'dora', 'anthrax'),
#  ('furnaced', 'dora', 'anthrax'),
#  ('nonfecund', 'dora', 'anthrax'),
#  ('unfecund', 'dora', 'anthrax'),
#  ('unfructed', 'dora', 'anthrax'),
#  ('confected', 'dura', 'anthrax'),
#  ('confed', 'dura', 'anthrax'),
#  ('conferted', 'dura', 'anthrax'),
#  ('confuted', 'dura', 'anthrax'),
#  ('cornfed', 'dura', 'anthrax'),
#  ('nonfecund', 'dura', 'anthrax'),
#  ('confected', 'dutra', 'anthrax'),
#  ('confed', 'dutra', 'anthrax'),
#  ('conferted', 'dutra', 'anthrax'),
#  ('confuted', 'dutra', 'anthrax'),
#  ('cornfed', 'dutra', 'anthrax'),
#  ('nonfecund', 'dutra', 'anthrax'),
#  ('confute', 'ecanda', 'anthrax'),
#  ('foeture', 'ecanda', 'anthrax'),
#  ('fondue', 'ecanda', 'anthrax'),
#  ('fronture', 'ecanda', 'anthrax'),
#  ('furore', 'ecanda', 'anthrax'),
#  ('fondue', 'echuca', 'anthrax'),
#  ('fronde', 'echuca', 'anthrax'),
#  ('confute', 'edana', 'anthrax'),
#  ('confute', 'edea', 'anthrax'),
#  ('confute', 'edna', 'anthrax'),
#  ('fondue', 'eruca', 'anthrax'),
#  ('fronde', 'eruca', 'anthrax'),
#  ('fondue', 'etcetera', 'anthrax'),
#  ('confrere', 'euda', 'anthrax'),
#  ('confronte', 'euda', 'anthrax'),
#  ('confute', 'euda', 'anthrax'),
#  ('feroce', 'euda', 'anthrax'),
#  ('foretrace', 'euda', 'anthrax'),
#  ('confrere', 'eudora', 'anthrax'),
#  ('confronte', 'eudora', 'anthrax'),
#  ('confute', 'eudora', 'anthrax'),
#  ('feroce', 'eudora', 'anthrax'),
#  ('foretrace', 'eudora', 'anthrax'),
#  ('fracture', 'eudora', 'anthrax'),
#  ('france', 'eudora', 'anthrax'),
#  ('fructure', 'eudora', 'anthrax'),
#  ('fucaceae', 'eudora', 'anthrax'),
#  ('furnace', 'eudora', 'anthrax'),
#  ('cauf', 'fedora', 'anthrax'),
#  ('curf', 'fedora', 'anthrax'),
#  ('fedn', 'noctua', 'anthrax'),
#  ('underfo', 'oca', 'anthrax'),
#  ('underfo', 'ochotona', 'anthrax'),
#  ('underfo', 'ochrana', 'anthrax'),
#  ('underfo', 'ochrea', 'anthrax'),
#  ('underfo', 'ocotea', 'anthrax'),
#  ('underfo', 'onca', 'anthrax'),
#  ('confuter', 'rada', 'anthrax'),
#  ('confeder', 'redunca', 'anthrax'),
#  ('confer', 'redunca', 'anthrax'),
#  ('confr', 'redunca', 'anthrax'),
#  ('confuter', 'redunca', 'anthrax'),
#  ('defector', 'redunca', 'anthrax'),
#  ('fetor', 'redunca', 'anthrax'),
#  ('foder', 'redunca', 'anthrax'),
#  ('foetor', 'redunca', 'anthrax'),
#  ('fonder', 'redunca', 'anthrax'),
#  ('for', 'redunca', 'anthrax'),
#  ('forecar', 'redunca', 'anthrax'),
#  ('forfear', 'redunca', 'anthrax'),
#  ('frondeur', 'redunca', 'anthrax'),
#  ('fronter', 'redunca', 'anthrax'),
#  ('functor', 'redunca', 'anthrax'),
#  ('furor', 'redunca', 'anthrax'),
#  ('ofer', 'redunca', 'anthrax'),
#  ('reconfer', 'redunca', 'anthrax'),
#  ('refractor', 'redunca', 'anthrax'),
#  ('chaufer', 'rhoda', 'anthrax'),
#  ('confuter', 'rhoda', 'anthrax'),
#  ('furnacer', 'rhoda', 'anthrax'),
#  ('chaufer', 'rhodora', 'anthrax'),
#  ('confuter', 'rhodora', 'anthrax'),
#  ('furnacer', 'rhodora', 'anthrax'),
#  ('chaufer', 'rhonda', 'anthrax'),
#  ('confuter', 'rhonda', 'anthrax'),
#  ('furnacer', 'rhonda', 'anthrax'),
#  ('confeder', 'rohuna', 'anthrax'),
#  ('defecter', 'rohuna', 'anthrax'),
#  ('defector', 'rohuna', 'anthrax'),
#  ('chaufer', 'rotonda', 'anthrax'),
#  ('confuter', 'rotonda', 'anthrax'),
#  ('furnacer', 'rotonda', 'anthrax'),
#  ('chaufer', 'rotunda', 'anthrax'),
#  ('confeder', 'rotunda', 'anthrax'),
#  ('confer', 'rotunda', 'anthrax'),
#  ('confuter', 'rotunda', 'anthrax'),
#  ('defecter', 'rotunda', 'anthrax'),
#  ('defector', 'rotunda', 'anthrax'),
#  ('forecar', 'rotunda', 'anthrax'),
#  ('furnacer', 'rotunda', 'anthrax'),
#  ('reconfer', 'rotunda', 'anthrax'),
#  ('refractor', 'rotunda', 'anthrax'),
#  ('confeder', 'rua', 'anthrax'),
#  ('defector', 'rua', 'anthrax'),
#  ('confeder', 'ruana', 'anthrax'),
#  ('defector', 'ruana', 'anthrax'),
#  ('confeder', 'rudera', 'anthrax'),
#  ('confer', 'rudera', 'anthrax'),
#  ('confr', 'rudera', 'anthrax'),
#  ('confuter', 'rudera', 'anthrax'),
#  ('defector', 'rudera', 'anthrax'),
#  ('forecar', 'rudera', 'anthrax'),
#  ('functor', 'rudera', 'anthrax'),
#  ('reconfer', 'rudera', 'anthrax'),
#  ('refractor', 'rudera', 'anthrax'),
#  ('defunct', 'tectona', 'anthrax'),
#  ('fondant', 'tecuna', 'anthrax'),
#  ('forthcut', 'teda', 'anthrax'),
#  ('defunct', 'toa', 'anthrax'),
#  ('defunct', 'toda', 'anthrax'),
#  ('feucht', 'toda', 'anthrax'),
#  ('defunct', 'todea', 'anthrax'),
#  ('feucht', 'todea', 'anthrax'),
#  ('forthcut', 'todea', 'anthrax'),
#  ('defunct', 'toea', 'anthrax'),
#  ('defunct', 'tonada', 'anthrax'),
#  ('feucht', 'tonada', 'anthrax'),
#  ('defunct', 'tora', 'anthrax'),
#  ('defunct', 'torana', 'anthrax'),
#  ('defunct', 'tornada', 'anthrax'),
#  ('feucht', 'tornada', 'anthrax'),
#  ('defunct', 'totora', 'anthrax'),
#  ('defunct', 'troca', 'anthrax'),
#  ('defunct', 'trocha', 'anthrax'),
#  ('defunct', 'trona', 'anthrax'),
#  ('confect', 'tucandera', 'anthrax'),
#  ('confort', 'tucandera', 'anthrax'),
#  ('confract', 'tucandera', 'anthrax'),
#  ('confront', 'tucandera', 'anthrax'),
#  ('fondant', 'tucandera', 'anthrax'),
#  ('font', 'tucandera', 'anthrax'),
#  ('foreact', 'tucandera', 'anthrax'),
#  ('forefront', 'tucandera', 'anthrax'),
#  ('foret', 'tucandera', 'anthrax'),
#  ('fort', 'tucandera', 'anthrax'),
#  ('forthcut', 'tucandera', 'anthrax'),
#  ('fot', 'tucandera', 'anthrax'),
#  ('front', 'tucandera', 'anthrax'),
#  ('frot', 'tucandera', 'anthrax'),
#  ('refont', 'tucandera', 'anthrax'),
#  ('refront', 'tucandera', 'anthrax'),
#  ('axfetch', 'hornada', 'antu'),
#  ('axfetch', 'honda', 'anunder'),
#  ('axfetch', 'honora', 'anunder'),
#  ('axfetch', 'hora', 'anunder'),
#  ('axfetch', 'hornada', 'anunder'),
#  ('axfetch', 'hotcha', 'anunder'),
#  ('axfetch', 'honda', 'anura'),
#  ('axfetch', 'hornada', 'anura'),
#  ('axfetch', 'honda', 'anuran'),
#  ('axfetch', 'hornada', 'anuran'),
#  ('fondue', 'externa', 'aonach'),
#  ('fondue', 'extra', 'aonach'),
#  ('fondue', 'externa', 'arach'),
#  ('fondue', 'extra', 'arach'),
#  ('axfetch', 'haraucana', 'arado'),
#  ('axfetch', 'honda', 'ararauna'),
#  ('axfetch', 'hornada', 'ararauna'),
#  ('axfetch', 'honda', 'araru'),
#  ('axfetch', 'hornada', 'araru'),
#  ('axfetch', 'honda', 'araua'),
#  ('axfetch', 'hornada', 'araua'),
#  ('axfetch', 'honda', 'arauan'),
#  ('axfetch', 'hornada', 'arauan'),
#  ('axfetch', 'honda', 'araucan'),
#  ('axfetch', 'hornada', 'araucan'),
#  ('axfetch', 'hadada', 'araucano'),
#  ('axfetch', 'honda', 'araucano'),
#  ('axfetch', 'hornada', 'araucano'),
#  ('axfetch', 'honda', 'arauna'),
#  ('axfetch', 'hornada', 'arauna'),
#  ('fondue', 'externa', 'areach'),
#  ('fondue', 'extra', 'areach'),
#  ('axfetch', 'honda', 'arecuna'),
#  ('axfetch', 'hornada', 'arecuna'),
#  ('coexerted', 'dhurna', 'arf'),
#  ('exhorter', 'redunca', 'arf'),
#  ('executer', 'rhonda', 'arf'),
#  ('executor', 'rhonda', 'arf'),
#  ('exhort', 'tucandera', 'arf'),
#  ('fondue', 'externa', 'arhauaco'),
#  ('fronde', 'externa', 'arhauaco'),
#  ('fondue', 'extra', 'arhauaco'),
#  ('fronde', 'extra', 'arhauaco'),
#  ('axfetch', 'honda', 'arhauaco'),
#  ('axfetch', 'hornada', 'arhauaco'),
#  ('axfetch', 'honda', 'arnaut'),
#  ('axfetch', 'hornada', 'arnaut'),
#  ('axfetch', 'honda', 'arnut'),
#  ('axfetch', 'hornada', 'arnut'),
#  ('axfetch', 'honda', 'arthur'),
#  ('axfetch', 'hornada', 'arthur'),
#  ('axfetch', 'honda', 'aru'),
#  ('axfetch', 'hornada', 'aru'),
#  ('axfetch', 'honda', 'aruac'),
#  ('axfetch', 'hornada', 'aruac'),
#  ('axfetch', 'hadada', 'arundo'),
#  ('axfetch', 'haha', 'arundo'),
#  ('axfetch', 'haraucana', 'arundo'),
#  ('axfetch', 'honda', 'arundo'),
#  ('axfetch', 'honora', 'arundo'),
#  ('axfetch', 'hora', 'arundo'),
#  ('axfetch', 'hornada', 'arundo'),
#  ('axfetch', 'hotcha', 'arundo'),
#  ('axfetch', 'huaca', 'arundo'),
#  ('axfetch', 'hura', 'arundo'),
#  ('confuted', 'dacha', 'arx'),
#  ('unfronted', 'dacha', 'arx'),
#  ('confuted', 'dha', 'arx'),
#  ('confuted', 'dharana', 'arx'),
#  ('confuted', 'dharna', 'arx'),
#  ('confected', 'dhaura', 'arx'),
#  ('conferted', 'dhaura', 'arx'),
#  ('confuted', 'dhaura', 'arx'),
#  ('confected', 'dhurna', 'arx'),
#  ('conferted', 'dhurna', 'arx'),
#  ('confuted', 'dhurna', 'arx'),
#  ('underfo', 'ochotona', 'arx'),
#  ('confuter', 'rhoda', 'arx'),
#  ('confuter', 'rhodora', 'arx'),
#  ('confuter', 'rhonda', 'arx'),
#  ('defecter', 'rohuna', 'arx'),
#  ('defector', 'rohuna', 'arx'),
#  ('chaufer', 'rotonda', 'arx'),
#  ('chaufer', 'rotunda', 'arx'),
#  ('feucht', 'tonada', 'arx'),
#  ('feucht', 'tornada', 'arx'),
#  ('defunct', 'trocha', 'arx'),
#  ('forthcut', 'tucandera', 'arx'),
#  ('axfetch', 'hornada', 'auca'),
#  ('axfetch', 'hornada', 'aucan'),
#  ('fondue', 'externa', 'aucht'),
#  ('fronde', 'externa', 'aucht'),
#  ('fondue', 'extra', 'aucht'),
#  ('fronde', 'extra', 'aucht'),
#  ('axfetch', 'hornada', 'aucht'),
#  ('axfetch', 'honda', 'auctor'),
#  ('axfetch', 'hornada', 'auctor'),
#  ('axfetch', 'honora', 'aud'),
#  ('axfetch', 'hornada', 'aud'),
#  ('axfetch', 'honora', 'audace'),
#  ('axfetch', 'hornada', 'audace'),
#  ('axfetch', 'honora', 'audad'),
#  ('axfetch', 'hornada', 'audad'),
#  ('axfetch', 'honora', 'audaean'),
#  ('axfetch', 'hora', 'audaean'),
#  ('axfetch', 'hornada', 'audaean'),
#  ('axfetch', 'hornada', 'aueto'),
#  ('coexerted', 'dharana', 'auf'),
#  ('coexerted', 'dharna', 'auf'),
#  ('coexerted', 'dhurna', 'auf'),
#  ('axfetch', 'hornada', 'auf'),
#  ('dextro', 'ochotona', 'auf'),
#  ('dextro', 'ochrana', 'auf'),
#  ('exhorter', 'redunca', 'auf'),
#  ('exacter', 'rhonda', 'auf'),
#  ('exactor', 'rhonda', 'auf'),
#  ('executer', 'rhonda', 'auf'),
#  ('executor', 'rhonda', 'auf'),
#  ('extractor', 'rhonda', 'auf'),
#  ('exhort', 'tucandera', 'auf'),
#  ('axfetch', 'hornada', 'auh'),
#  ('axfetch', 'hornada', 'auhuhu'),
#  ('axfetch', 'hornada', 'aunt'),
#  ('axfetch', 'honda', 'aunter'),
#  ('axfetch', 'hornada', 'aunter'),
#  ('axfetch', 'honda', 'auntre'),
#  ('axfetch', 'hornada', 'auntre'),
#  ('axfetch', 'honda', 'aura'),
#  ('axfetch', 'hornada', 'aura'),
#  ('axfetch', 'honda', 'aurae'),
#  ('axfetch', 'hornada', 'aurae'),
#  ('axfetch', 'honda', 'aurar'),
#  ('axfetch', 'hornada', 'aurar'),
#  ('fondue', 'externa', 'auroch'),
#  ('fronde', 'externa', 'auroch'),
#  ('fondue', 'extra', 'auroch'),
#  ('fronde', 'extra', 'auroch'),
#  ('axfetch', 'honda', 'auroch'),
#  ('axfetch', 'hornada', 'auroch'),
#  ('axfetch', 'honda', 'aurora'),
#  ('axfetch', 'hornada', 'aurora'),
#  ('axfetch', 'honda', 'aurorae'),
#  ('axfetch', 'hornada', 'aurorae'),
#  ('axfetch', 'honda', 'aurore'),
#  ('axfetch', 'hornada', 'aurore'),
#  ('axfetch', 'hadada', 'aurorean'),
#  ('axfetch', 'honda', 'aurorean'),
#  ('axfetch', 'hornada', 'aurorean'),
#  ('axfetch', 'honda', 'aurure'),
#  ('axfetch', 'hornada', 'aurure'),
#  ('axfetch', 'hornada', 'aute'),
#  ('axfetch', 'honda', 'autere'),
#  ('axfetch', 'hornada', 'autere'),
#  ('axfetch', 'honda', 'auteur'),
#  ('axfetch', 'hornada', 'auteur'),
#  ('axfetch', 'hornada', 'auth'),
#  ('axfetch', 'honda', 'author'),
#  ('axfetch', 'hornada', 'author'),
#  ('confrere', 'externa', 'authored'),
#  ('confronte', 'externa', 'authored'),
#  ('confute', 'externa', 'authored'),
#  ('feroce', 'externa', 'authored'),
#  ('foretrace', 'externa', 'authored'),
#  ('fracture', 'externa', 'authored'),
#  ('france', 'externa', 'authored'),
#  ('fructure', 'externa', 'authored'),
#  ('fucaceae', 'externa', 'authored'),
#  ('furnace', 'externa', 'authored'),
#  ('confrere', 'extra', 'authored'),
#  ('confronte', 'extra', 'authored'),
#  ('confute', 'extra', 'authored'),
#  ('france', 'extra', 'authored'),
#  ('furnace', 'extra', 'authored'),
#  ('xref', 'franca', 'authored'),
#  ('xref', 'furacana', 'authored'),
#  ('axfetch', 'haraucana', 'authored'),
#  ('axfetch', 'honda', 'authored'),
#  ('axfetch', 'honora', 'authored'),
#  ('axfetch', 'hornada', 'authored'),
#  ('axfetch', 'hornada', 'auto'),
#  ('axfetch', 'haraucana', 'autocade'),
#  ('axfetch', 'honora', 'autocade'),
#  ('axfetch', 'hornada', 'autocade'),
#  ('axfetch', 'honda', 'autocar'),
#  ('axfetch', 'hornada', 'autocar'),
#  ('fondue', 'externa', 'autochton'),
#  ('fronde', 'externa', 'autochton'),
#  ('fondue', 'extra', 'autochton'),
#  ('fronde', 'extra', 'autochton'),
#  ('xref', 'fedora', 'autochton'),
#  ('axfetch', 'hornada', 'autochton'),
#  ('axfetch', 'haraucana', 'autocoder'),
#  ('axfetch', 'honda', 'autocoder'),
#  ('axfetch', 'honora', 'autocoder'),
#  ('axfetch', 'hornada', 'autocoder'),
#  ('axfetch', 'hornada', 'autocue'),
#  ('axfetch', 'haraucana', 'autoed'),
#  ('axfetch', 'honora', 'autoed'),
#  ('axfetch', 'hornada', 'autoed'),
#  ('axfetch', 'honda', 'autor'),
#  ('axfetch', 'hornada', 'autor'),
#  ('axfetch', 'honda', 'autre'),
#  ('axfetch', 'hornada', 'autre'),
#  ('unfronted', 'dacha', 'axe'),
#  ('confuted', 'dharana', 'axe'),
#  ('confuted', 'dharna', 'axe'),
#  ('confected', 'dhaura', 'axe'),
#  ('conferted', 'dhaura', 'axe'),
#  ('confuted', 'dhaura', 'axe'),
#  ('confected', 'dhurna', 'axe'),
#  ('conferted', 'dhurna', 'axe'),
#  ('confuted', 'dhurna', 'axe'),
#  ('underfo', 'ochotona', 'axe'),
#  ('confuter', 'rhoda', 'axe'),
#  ('functor', 'rhoda', 'axe'),
#  ('confuter', 'rhodora', 'axe'),
#  ('functor', 'rhodora', 'axe'),
#  ('confuter', 'rhonda', 'axe'),
#  ('fractur', 'rhonda', 'axe'),
#  ('functor', 'rhonda', 'axe'),
#  ('defecter', 'rohuna', 'axe'),
#  ('defector', 'rohuna', 'axe'),
#  ('chaufer', 'rotonda', 'axe'),
#  ('chaufer', 'rotunda', 'axe'),
#  ('fchar', 'rotunda', 'axe'),
#  ('forthcut', 'tonada', 'axe'),
#  ('feucht', 'tornada', 'axe'),
#  ('forthcut', 'tornada', 'axe'),
#  ('defunct', 'trocha', 'axe'),
#  ('fondant', 'trucha', 'axe'),
#  ('forthcut', 'tucandera', 'axe'),
#  ('unfronted', 'dacha', 'axed'),
#  ('confuted', 'dharana', 'axed'),
#  ('confuted', 'dharna', 'axed'),
#  ('confected', 'dhaura', 'axed'),
#  ('conferted', 'dhaura', 'axed'),
#  ('confuted', 'dhaura', 'axed'),
#  ('confected', 'dhurna', 'axed'),
#  ('conferted', 'dhurna', 'axed'),
#  ('confuted', 'dhurna', 'axed'),
#  ('confronte', 'echuca', 'axed'),
#  ('fronture', 'echuca', 'axed'),
#  ('thof', 'furacana', 'axed'),
#  ('ferforth', 'haraucana', 'axed'),
#  ('foreteach', 'haraucana', 'axed'),
#  ('forth', 'haraucana', 'axed'),
#  ('fotch', 'haraucana', 'axed'),
#  ('froth', 'haraucana', 'axed'),
#  ('fraunch', 'hotcha', 'axed'),
#  ('chanfron', 'noctua', 'axed'),
#  ('ferahan', 'noctua', 'axed'),
#  ('forthon', 'noctua', 'axed'),
#  ('foreturn', 'nucha', 'axed'),
#  ('forthon', 'nucha', 'axed'),
#  ('fortran', 'nucha', 'axed'),
#  ('fronton', 'nucha', 'axed'),
#  ('toforn', 'nucha', 'axed'),
#  ('futuro', 'ochotona', 'axed'),
#  ('underfo', 'ochotona', 'axed'),
#  ('futuro', 'ochrana', 'axed'),
#  ('confuter', 'rha', 'axed'),
#  ('functor', 'rha', 'axed'),
#  ('confuter', 'rhoda', 'axed'),
#  ('functor', 'rhoda', 'axed'),
#  ('confuter', 'rhodora', 'axed'),
#  ('functor', 'rhodora', 'axed'),
#  ('confuter', 'rhonda', 'axed'),
#  ('fractur', 'rhonda', 'axed'),
#  ('functor', 'rhonda', 'axed'),
#  ('confuter', 'rohuna', 'axed'),
#  ('defecter', 'rohuna', 'axed'),
#  ('defector', 'rohuna', 'axed'),
#  ('fractur', 'rohuna', 'axed'),
#  ('functor', 'rohuna', 'axed'),
#  ('refractor', 'rohuna', 'axed'),
#  ('chaufer', 'rotonda', 'axed'),
#  ('chaufer', 'rotunda', 'axed'),
#  ('fchar', 'rotunda', 'axed'),
#  ('forthcut', 'tectona', 'axed'),
#  ('forthcut', 'tecuna', 'axed'),
#  ('forthcut', 'terna', 'axed'),
#  ('forthcut', 'thana', 'axed'),
#  ('forthcut', 'tonada', 'axed'),
#  ('feucht', 'torana', 'axed'),
#  ('forthcut', 'torana', 'axed'),
#  ('feucht', 'tornada', 'axed'),
#  ('forthcut', 'tornada', 'axed'),
#  ('defunct', 'trocha', 'axed'),
#  ('funt', 'trocha', 'axed'),
#  ('unfret', 'trocha', 'axed'),
#  ('feucht', 'trona', 'axed'),
#  ('forthcut', 'trona', 'axed'),
#  ('confect', 'trucha', 'axed'),
#  ('confort', 'trucha', 'axed'),
#  ('confract', 'trucha', 'axed'),
#  ('confront', 'trucha', 'axed'),
#  ('fondant', 'trucha', 'axed'),
#  ('font', 'trucha', 'axed'),
#  ('forefront', 'trucha', 'axed'),
#  ('front', 'trucha', 'axed'),
#  ('refont', 'trucha', 'axed'),
#  ('refront', 'trucha', 'axed'),
#  ('forthcut', 'tucana', 'axed'),
#  ('forthcut', 'tucandera', 'axed'),
#  ('forthcut', 'tucuna', 'axed'),
#  ('forthcut', 'tuna', 'axed'),
#  ('forthcut', 'tunca', 'axed'),
#  ('confuted', 'dacha', 'axer'),
#  ('unfronted', 'dacha', 'axer'),
#  ('confuted', 'dha', 'axer'),
#  ('confuted', 'dharana', 'axer'),
#  ('confuted', 'dharna', 'axer'),
#  ('confected', 'dhaura', 'axer'),
#  ('conferted', 'dhaura', 'axer'),
#  ('confuted', 'dhaura', 'axer'),
#  ('confected', 'dhurna', 'axer'),
#  ('conferted', 'dhurna', 'axer'),
#  ('confuted', 'dhurna', 'axer'),
#  ('underfo', 'ochotona', 'axer'),
#  ('confuter', 'rhoda', 'axer'),
#  ('functor', 'rhoda', 'axer'),
#  ('confuter', 'rhodora', 'axer'),
#  ('functor', 'rhodora', 'axer'),
#  ('confuter', 'rhonda', 'axer'),
#  ('fractur', 'rhonda', 'axer'),
#  ('functor', 'rhonda', 'axer'),
#  ('defecter', 'rohuna', 'axer'),
#  ('defector', 'rohuna', 'axer'),
#  ('chaufer', 'rotonda', 'axer'),
#  ('chaufer', 'rotunda', 'axer'),
#  ('fchar', 'rotunda', 'axer'),
#  ('feucht', 'tonada', 'axer'),
#  ('forthcut', 'tonada', 'axer'),
#  ('feucht', 'tornada', 'axer'),
#  ('forthcut', 'tornada', 'axer'),
#  ('defunct', 'trocha', 'axer'),
#  ('fondant', 'trucha', 'axer'),
#  ('forthcut', 'tucandera', 'axer'),
#  ('eudora', 'acana', 'axfetch'),
#  ('rotunda', 'acana', 'axfetch'),
#  ('eudora', 'acantha', 'axfetch'),
#  ('rotunda', 'acantha', 'axfetch'),
#  ('rotunda', 'acara', 'axfetch'),
#  ('aduana', 'acorea', 'axfetch'),
#  ('caraunda', 'acorea', 'axfetch'),
#  ('daurna', 'acorea', 'axfetch'),
#  ('dhurna', 'acorea', 'axfetch'),
#  ('nuda', 'acorea', 'axfetch'),
#  ('redunca', 'acorea', 'axfetch'),
#  ('rotunda', 'acorea', 'axfetch'),
#  ('tucandera', 'acorea', 'axfetch'),
#  ('cornua', 'ada', 'axfetch'),
#  ('rohuna', 'ada', 'axfetch'),
#  ('rotunda', 'ada', 'axfetch'),
#  ('ahura', 'adeona', 'axfetch'),
#  ('anura', 'adeona', 'axfetch'),
#  ('ararauna', 'adeona', 'axfetch'),
#  ('araua', 'adeona', 'axfetch'),
#  ('arauna', 'adeona', 'axfetch'),
#  ('arecuna', 'adeona', 'axfetch'),
#  ('aura', 'adeona', 'axfetch'),
#  ('aurora', 'adeona', 'axfetch'),
#  ('carauna', 'adeona', 'axfetch'),
#  ('caraunda', 'adeona', 'axfetch'),
#  ('carua', 'adeona', 'axfetch'),
#  ('chaetura', 'adeona', 'axfetch'),
#  ('chuhra', 'adeona', 'axfetch'),
#  ('churada', 'adeona', 'axfetch'),
#  ('cornua', 'adeona', 'axfetch'),
#  ('cucaracha', 'adeona', 'axfetch'),
#  ('cura', 'adeona', 'axfetch'),
#  ('curacoa', 'adeona', 'axfetch'),
#  ('curara', 'adeona', 'axfetch'),
#  ('curua', 'adeona', 'axfetch'),
#  ('daurna', 'adeona', 'axfetch'),
#  ('dhaura', 'adeona', 'axfetch'),
#  ('dhurna', 'adeona', 'axfetch'),
#  ('dura', 'adeona', 'axfetch'),
#  ('dutra', 'adeona', 'axfetch'),
#  ('eruca', 'adeona', 'axfetch'),
#  ('eudora', 'adeona', 'axfetch'),
#  ('furacana', 'adeona', 'axfetch'),
#  ('haraucana', 'adeona', 'axfetch'),
#  ('hura', 'adeona', 'axfetch'),
#  ('redunca', 'adeona', 'axfetch'),
#  ('rohuna', 'adeona', 'axfetch'),
#  ('rotunda', 'adeona', 'axfetch'),
#  ('rua', 'adeona', 'axfetch'),
#  ('ruana', 'adeona', 'axfetch'),
#  ('rudera', 'adeona', 'axfetch'),
#  ('trucha', 'adeona', 'axfetch'),
#  ('tucandera', 'adeona', 'axfetch'),
#  ('ura', 'adeona', 'axfetch'),
#  ('urea', 'adeona', 'axfetch'),
#  ('urethra', 'adeona', 'axfetch'),
#  ('urna', 'adeona', 'axfetch'),
#  ('chuchona', 'adhara', 'axfetch'),
#  ('cornua', 'adhara', 'axfetch'),
#  ('noctua', 'adhara', 'axfetch'),
#  ('rohuna', 'adhara', 'axfetch'),
#  ('rotunda', 'adhara', 'axfetch'),
#  ('unona', 'adhara', 'axfetch'),
#  ('acorea', 'aduana', 'axfetch'),
#  ('ancora', 'aduana', 'axfetch'),
#  ('aotearoa', 'aduana', 'axfetch'),
#  ('aurora', 'aduana', 'axfetch'),
#  ('caracoa', 'aduana', 'axfetch'),
#  ('caracora', 'aduana', 'axfetch'),
#  ('caroa', 'aduana', 'axfetch'),
#  ('chora', 'aduana', 'axfetch'),
#  ('chorea', 'aduana', 'axfetch'),
#  ('contra', 'aduana', 'axfetch'),
#  ('contrada', 'aduana', 'axfetch'),
#  ('cora', 'aduana', 'axfetch'),
#  ('cornada', 'aduana', 'axfetch'),
#  ('cornua', 'aduana', 'axfetch'),
#  ('coroa', 'aduana', 'axfetch'),
#  ('corona', 'aduana', 'axfetch'),
#  ('curacoa', 'aduana', 'axfetch'),
#  ('deodara', 'aduana', 'axfetch'),
#  ('dora', 'aduana', 'axfetch'),
#  ('eudora', 'aduana', 'axfetch'),
#  ('fedora', 'aduana', 'axfetch'),
#  ('fora', 'aduana', 'axfetch'),
#  ('honora', 'aduana', 'axfetch'),
#  ('hora', 'aduana', 'axfetch'),
#  ('hornada', 'aduana', 'axfetch'),
#  ('nora', 'aduana', 'axfetch'),
#  ('norna', 'aduana', 'axfetch'),
#  ('ochrana', 'aduana', 'axfetch'),
#  ('ochrea', 'aduana', 'axfetch'),
#  ('ora', 'aduana', 'axfetch'),
#  ('orna', 'aduana', 'axfetch'),
#  ('rhoda', 'aduana', 'axfetch'),
#  ('rhodora', 'aduana', 'axfetch'),
#  ('rhonda', 'aduana', 'axfetch'),
#  ('rohuna', 'aduana', 'axfetch'),
#  ('rotonda', 'aduana', 'axfetch'),
#  ('rotunda', 'aduana', 'axfetch'),
#  ('tora', 'aduana', 'axfetch'),
#  ('torana', 'aduana', 'axfetch'),
#  ('tornada', 'aduana', 'axfetch'),
#  ('totora', 'aduana', 'axfetch'),
#  ('troca', 'aduana', 'axfetch'),
#  ('trocha', 'aduana', 'axfetch'),
#  ('trona', 'aduana', 'axfetch'),
#  ('rotunda', 'aha', 'axfetch'),
#  ('contrada', 'ahuaca', 'axfetch'),
#  ('cornada', 'ahuaca', 'axfetch'),
#  ('hornada', 'ahuaca', 'axfetch'),
#  ('rhonda', 'ahuaca', 'axfetch'),
#  ('rotonda', 'ahuaca', 'axfetch'),
#  ('rotunda', 'ahuaca', 'axfetch'),
#  ('tornada', 'ahuaca', 'axfetch'),
#  ('adeona', 'ahura', 'axfetch'),
#  ('anaconda', 'ahura', 'axfetch'),
#  ('contrada', 'ahura', 'axfetch'),
#  ('cornada', 'ahura', 'axfetch'),
#  ('dodona', 'ahura', 'axfetch'),
#  ('dodonaea', 'ahura', 'axfetch'),
#  ('dona', 'ahura', 'axfetch'),
#  ('honda', 'ahura', 'axfetch'),
#  ('hornada', 'ahura', 'axfetch'),
#  ('nonda', 'ahura', 'axfetch'),
#  ...]

# %%
# puzzle = ['omt',
#           'uri',
#           'haf',
#           'lpg']
# puzzle_set = set(''.join(puzzle))

# words_possible = [word for word in words if not (set(word) - puzzle_set)]   
# alphabet = 'abcdefghijklmnopqrstuvwxyz'

# not_in_puzzle = set(alphabet) -  puzzle_set

# 132 ms
# %timeit words_possible = [word for word in words if not set(word) & not_in_puzzle] 

# 350 ms
# %timeit words_possible = [word for word in words if all([letter in ''.join(puzzle) for letter in word])]
