# %%
# get list of english words
# words must be 3 to 9 characters long and have a vowel
# dictionary = 'words_alpha.txt'
dictionary ='/usr/share/dict/words'
with open(dictionary) as f:
    words = f.read().splitlines()

words = [w for w in words if len(w) >= 3 and len(w) <= 9 and any(v in w for v in 'aeiouy')]
print(len(words))
# Out:
# 120931

# %%
puzzle = 'enrtblaoipxs'

# %%
# find words that are possible to make in the puzzle

words_valid = []
for w in words:
    valid = True
    idx_last = (puzzle.find(w[0]) // 3) + 1
    if not idx_last:
        continue
    for c in w[1:]:
        idx = (puzzle.find(c) // 3) + 1
        if idx == idx_last or not idx:
            valid = False
            break
        idx_last = idx
    if valid:
        words_valid.append(w)
print(len(words_valid))
# Out:
# 969

# %%
# valid pairs have last and first letters matching 
valid_pairs = [(w1,w2) for w2 in words_valid for w1 in words_valid if w2[0] == w1[-1]] 
two_word_solutions = [(w1,w2) for w1, w2 in valid_pairs if len(set(w1+w2)) == len(puzzle)]
print(len(valid_pairs))
print(len(two_word_solutions))
two_word_solutions
# Out:
# 71862
# 8
# [('panse', 'exorbital'),
#  ('saponite', 'exorbital'),
#  ('sinople', 'exorbital'),
#  ('snape', 'exorbital'),
#  ('snipe', 'exorbital'),
#  ('protaxis', 'snibel'),
#  ('soleprint', 'teabox'),
#  ('obeisant', 'triplex')]

# %%
# valid triples have last and first letters matching 
valid_triples = [(w1,w2,w3) for w3 in words_valid for w1,w2 in valid_pairs if w3[0] == w2[-1]]
print(len(valid_triples))
# Out:
# 5430279

# %%
three_word_solutions = [(w1,w2,w3) for w1,w2,w3 in valid_triples if len(set(w1+w2+w3)) == len(puzzle)]
print(len(three_word_solutions))
three_word_solutions
# Out:
# 11064
# [('antipole', 'exostra', 'abet'),
#  ('pantile', 'exostra', 'abet'),
#  ('pinole', 'exostra', 'abet'),
#  ('pontile', 'exostra', 'abet'),
#  ('rantipole', 'exostra', 'abet'),
#  ('sinople', 'exostra', 'abet'),
#  ('sinople', 'extra', 'abet'),
#  ('soleprint', 'toxa', 'abet'),
#  ('antipole', 'exostra', 'abilo'),
#  ('nape', 'exostra', 'abilo'),
#  ('nope', 'exostra', 'abilo'),
#  ('panse', 'exostra', 'abilo'),
#  ('pantie', 'exostra', 'abilo'),
#  ('pantile', 'exostra', 'abilo'),
#  ('pinole', 'exostra', 'abilo'),
#  ('pinte', 'exostra', 'abilo'),
#  ('pontile', 'exostra', 'abilo'),
#  ('pronate', 'exostra', 'abilo'),
#  ('rantipole', 'exostra', 'abilo'),
#  ('saponite', 'exostra', 'abilo'),
#  ('sinople', 'exostra', 'abilo'),
#  ('snape', 'exostra', 'abilo'),
#  ('snipe', 'exostra', 'abilo'),
#  ('panse', 'extra', 'abilo'),
#  ('saponite', 'extra', 'abilo'),
#  ('sinople', 'extra', 'abilo'),
#  ('snape', 'extra', 'abilo'),
#  ('snipe', 'extra', 'abilo'),
#  ('soleprint', 'toxa', 'abilo'),
#  ('antipole', 'exostra', 'abir'),
#  ('pantile', 'exostra', 'abir'),
#  ('pinole', 'exostra', 'abir'),
#  ('pontile', 'exostra', 'abir'),
#  ('rantipole', 'exostra', 'abir'),
#  ('sinople', 'exostra', 'abir'),
#  ('sinople', 'extra', 'abir'),
#  ('aseptolin', 'noxa', 'abir'),
#  ('plastein', 'noxa', 'abir'),
#  ('pleonast', 'toxa', 'abir'),
#  ('soleprint', 'toxa', 'abir'),
#  ('antipole', 'exostra', 'abiston'),
#  ('aplite', 'exostra', 'abiston'),
#  ('aslope', 'exostra', 'abiston'),
#  ('lipase', 'exostra', 'abiston'),
#  ('lope', 'exostra', 'abiston'),
#  ('olpe', 'exostra', 'abiston'),
#  ('pale', 'exostra', 'abiston'),
#  ('pantile', 'exostra', 'abiston'),
#  ('parle', 'exostra', 'abiston'),
#  ('parole', 'exostra', 'abiston'),
#  ('partile', 'exostra', 'abiston'),
#  ('pastile', 'exostra', 'abiston'),
#  ('pile', 'exostra', 'abiston'),
#  ('pilose', 'exostra', 'abiston'),
#  ('pinole', 'exostra', 'abiston'),
#  ('pistole', 'exostra', 'abiston'),
#  ('plate', 'exostra', 'abiston'),
#  ('plote', 'exostra', 'abiston'),
#  ('pole', 'exostra', 'abiston'),
#  ('polite', 'exostra', 'abiston'),
#  ('pontile', 'exostra', 'abiston'),
#  ('prolate', 'exostra', 'abiston'),
#  ('rantipole', 'exostra', 'abiston'),
#  ('saple', 'exostra', 'abiston'),
#  ('saprolite', 'exostra', 'abiston'),
#  ('sinople', 'exostra', 'abiston'),
#  ('sirple', 'exostra', 'abiston'),
#  ('slape', 'exostra', 'abiston'),
#  ('slipe', 'exostra', 'abiston'),
#  ('slope', 'exostra', 'abiston'),
#  ('staple', 'exostra', 'abiston'),
#  ('tiple', 'exostra', 'abiston'),
#  ('triple', 'exostra', 'abiston'),
#  ('antipole', 'extra', 'abiston'),
#  ('aplite', 'extra', 'abiston'),
#  ('aslope', 'extra', 'abiston'),
#  ('lipase', 'extra', 'abiston'),
#  ('lope', 'extra', 'abiston'),
#  ('olpe', 'extra', 'abiston'),
#  ('pale', 'extra', 'abiston'),
#  ('pantile', 'extra', 'abiston'),
#  ('parle', 'extra', 'abiston'),
#  ('parole', 'extra', 'abiston'),
#  ('partile', 'extra', 'abiston'),
#  ('pastile', 'extra', 'abiston'),
#  ('pile', 'extra', 'abiston'),
#  ('pilose', 'extra', 'abiston'),
#  ('pinole', 'extra', 'abiston'),
#  ('pistole', 'extra', 'abiston'),
#  ('plate', 'extra', 'abiston'),
#  ('plote', 'extra', 'abiston'),
#  ('pole', 'extra', 'abiston'),
#  ('polite', 'extra', 'abiston'),
#  ('pontile', 'extra', 'abiston'),
#  ('prolate', 'extra', 'abiston'),
#  ('rantipole', 'extra', 'abiston'),
#  ('saple', 'extra', 'abiston'),
#  ('saprolite', 'extra', 'abiston'),
#  ('sinople', 'extra', 'abiston'),
#  ('sirple', 'extra', 'abiston'),
#  ('slape', 'extra', 'abiston'),
#  ('slipe', 'extra', 'abiston'),
#  ('slope', 'extra', 'abiston'),
#  ('staple', 'extra', 'abiston'),
#  ('tiple', 'extra', 'abiston'),
#  ('triple', 'extra', 'abiston'),
#  ('exorbital', 'lepa', 'abiston'),
#  ('axil', 'lepra', 'abiston'),
#  ('exorbital', 'lepra', 'abiston'),
#  ('extol', 'lepra', 'abiston'),
#  ('noxal', 'lepra', 'abiston'),
#  ('exorbital', 'lipa', 'abiston'),
#  ('pearlin', 'noxa', 'abiston'),
#  ('oxlip', 'petrosa', 'abiston'),
#  ('oxlip', 'protea', 'abiston'),
#  ('plexor', 'ripa', 'abiston'),
#  ('sexipolar', 'ripa', 'abiston'),
#  ('plexor', 'rita', 'abiston'),
#  ('sexipolar', 'rita', 'abiston'),
#  ('plexor', 'rota', 'abiston'),
#  ('sexipolar', 'rota', 'abiston'),
#  ('polaxis', 'sirpea', 'abiston'),
#  ('praxis', 'solea', 'abiston'),
#  ('protaxis', 'solea', 'abiston'),
#  ('praxis', 'stela', 'abiston'),
#  ('protaxis', 'stela', 'abiston'),
#  ('soleprint', 'toxa', 'abiston'),
#  ('antipole', 'exostra', 'abort'),
#  ('pantile', 'exostra', 'abort'),
#  ('pinole', 'exostra', 'abort'),
#  ('pontile', 'exostra', 'abort'),
#  ('rantipole', 'exostra', 'abort'),
#  ('sinople', 'exostra', 'abort'),
#  ('sinople', 'extra', 'abort'),
#  ('aseptolin', 'noxa', 'abort'),
#  ('plastein', 'noxa', 'abort'),
#  ('soleprint', 'toxa', 'abort'),
#  ('antipole', 'exostra', 'abortin'),
#  ('aplite', 'exostra', 'abortin'),
#  ('aslope', 'exostra', 'abortin'),
#  ('lipase', 'exostra', 'abortin'),
#  ('lope', 'exostra', 'abortin'),
#  ('olpe', 'exostra', 'abortin'),
#  ('pale', 'exostra', 'abortin'),
#  ('pantile', 'exostra', 'abortin'),
#  ('parle', 'exostra', 'abortin'),
#  ('parole', 'exostra', 'abortin'),
#  ('partile', 'exostra', 'abortin'),
#  ('pastile', 'exostra', 'abortin'),
#  ('pile', 'exostra', 'abortin'),
#  ('pilose', 'exostra', 'abortin'),
#  ('pinole', 'exostra', 'abortin'),
#  ('pistole', 'exostra', 'abortin'),
#  ('plate', 'exostra', 'abortin'),
#  ('plote', 'exostra', 'abortin'),
#  ('pole', 'exostra', 'abortin'),
#  ('polite', 'exostra', 'abortin'),
#  ('pontile', 'exostra', 'abortin'),
#  ('prolate', 'exostra', 'abortin'),
#  ('rantipole', 'exostra', 'abortin'),
#  ('saple', 'exostra', 'abortin'),
#  ('saprolite', 'exostra', 'abortin'),
#  ('sinople', 'exostra', 'abortin'),
#  ('sirple', 'exostra', 'abortin'),
#  ('slape', 'exostra', 'abortin'),
#  ('slipe', 'exostra', 'abortin'),
#  ('slope', 'exostra', 'abortin'),
#  ('staple', 'exostra', 'abortin'),
#  ('tiple', 'exostra', 'abortin'),
#  ('triple', 'exostra', 'abortin'),
#  ('aslope', 'extra', 'abortin'),
#  ('lipase', 'extra', 'abortin'),
#  ('pastile', 'extra', 'abortin'),
#  ('pilose', 'extra', 'abortin'),
#  ('pistole', 'extra', 'abortin'),
#  ('saple', 'extra', 'abortin'),
#  ('saprolite', 'extra', 'abortin'),
#  ('sinople', 'extra', 'abortin'),
#  ('sirple', 'extra', 'abortin'),
#  ('slape', 'extra', 'abortin'),
#  ('slipe', 'extra', 'abortin'),
#  ('slope', 'extra', 'abortin'),
#  ('staple', 'extra', 'abortin'),
#  ('aseptolin', 'noxa', 'abortin'),
#  ('plastein', 'noxa', 'abortin'),
#  ('oxlip', 'pesa', 'abortin'),
#  ('oxlip', 'petrosa', 'abortin'),
#  ('sexipolar', 'ripa', 'abortin'),
#  ('sexipolar', 'rita', 'abortin'),
#  ('sexipolar', 'rota', 'abortin'),
#  ('polaxis', 'sea', 'abortin'),
#  ('polaxis', 'septa', 'abortin'),
#  ('polaxis', 'seta', 'abortin'),
#  ('polaxis', 'sirpea', 'abortin'),
#  ('polaxis', 'solea', 'abortin'),
#  ('praxis', 'solea', 'abortin'),
#  ('protaxis', 'solea', 'abortin'),
#  ('polaxis', 'stela', 'abortin'),
#  ('praxis', 'stela', 'abortin'),
#  ('protaxis', 'stela', 'abortin'),
#  ('pleonast', 'toxa', 'abortin'),
#  ('slept', 'toxa', 'abortin'),
#  ('soleprint', 'toxa', 'abortin'),
#  ('saprolite', 'etna', 'abox'),
#  ('sirple', 'etna', 'abox'),
#  ('antipole', 'exostra', 'abox'),
#  ('pantile', 'exostra', 'abox'),
#  ('pinole', 'exostra', 'abox'),
#  ('pontile', 'exostra', 'abox'),
#  ('rantipole', 'exostra', 'abox'),
#  ('sinople', 'exostra', 'abox'),
#  ('sinople', 'extra', 'abox'),
#  ('nostril', 'lepa', 'abox'),
#  ('nostril', 'lepra', 'abox'),
#  ('tinsel', 'lepra', 'abox'),
#  ('tonsil', 'lepra', 'abox'),
#  ('petrosal', 'lina', 'abox'),
#  ('priestal', 'lina', 'abox'),
#  ('plastron', 'niepa', 'abox'),
#  ('nirles', 'septa', 'abox'),
#  ('nirles', 'stopa', 'abox'),
#  ('panties', 'strobila', 'abox'),
#  ('pelanos', 'strobila', 'abox'),
#  ('pontes', 'strobila', 'abox'),
#  ('soleprint', 'tea', 'abox'),
#  ('soleprint', 'tinosa', 'abox'),
#  ('pleonast', 'tobira', 'abox'),
#  ('soleprint', 'tobira', 'abox'),
#  ('soleprint', 'tora', 'abox'),
#  ('soleprint', 'toxa', 'abox'),
#  ('soleprint', 'tra', 'abox'),
#  ('soleprint', 'trona', 'abox'),
#  ('antipole', 'exostra', 'abrin'),
#  ('aplite', 'exostra', 'abrin'),
#  ('aslope', 'exostra', 'abrin'),
#  ('lipase', 'exostra', 'abrin'),
#  ('lope', 'exostra', 'abrin'),
#  ('olpe', 'exostra', 'abrin'),
#  ('pale', 'exostra', 'abrin'),
#  ('pantile', 'exostra', 'abrin'),
#  ('parle', 'exostra', 'abrin'),
#  ('parole', 'exostra', 'abrin'),
#  ('partile', 'exostra', 'abrin'),
#  ('pastile', 'exostra', 'abrin'),
#  ('pile', 'exostra', 'abrin'),
#  ('pilose', 'exostra', 'abrin'),
#  ('pinole', 'exostra', 'abrin'),
#  ('pistole', 'exostra', 'abrin'),
#  ('plate', 'exostra', 'abrin'),
#  ('plote', 'exostra', 'abrin'),
#  ('pole', 'exostra', 'abrin'),
#  ('polite', 'exostra', 'abrin'),
#  ('pontile', 'exostra', 'abrin'),
#  ('prolate', 'exostra', 'abrin'),
#  ('rantipole', 'exostra', 'abrin'),
#  ('saple', 'exostra', 'abrin'),
#  ('saprolite', 'exostra', 'abrin'),
#  ('sinople', 'exostra', 'abrin'),
#  ('sirple', 'exostra', 'abrin'),
#  ('slape', 'exostra', 'abrin'),
#  ('slipe', 'exostra', 'abrin'),
#  ('slope', 'exostra', 'abrin'),
#  ('staple', 'exostra', 'abrin'),
#  ('tiple', 'exostra', 'abrin'),
#  ('triple', 'exostra', 'abrin'),
#  ('aslope', 'extra', 'abrin'),
#  ('pilose', 'extra', 'abrin'),
#  ('pistole', 'extra', 'abrin'),
#  ('saprolite', 'extra', 'abrin'),
#  ('sinople', 'extra', 'abrin'),
#  ('slope', 'extra', 'abrin'),
#  ('aseptolin', 'noxa', 'abrin'),
#  ('plastein', 'noxa', 'abrin'),
#  ('oxlip', 'petrosa', 'abrin'),
#  ('sexipolar', 'rita', 'abrin'),
#  ('sexipolar', 'rota', 'abrin'),
#  ('polaxis', 'septa', 'abrin'),
#  ('polaxis', 'seta', 'abrin'),
#  ('protaxis', 'solea', 'abrin'),
#  ('polaxis', 'stela', 'abrin'),
#  ('protaxis', 'stela', 'abrin'),
#  ('pleonast', 'toxa', 'abrin'),
#  ('slept', 'toxa', 'abrin'),
#  ('soleprint', 'toxa', 'abrin'),
#  ('antipole', 'exostra', 'absit'),
#  ('pantile', 'exostra', 'absit'),
#  ('pinole', 'exostra', 'absit'),
#  ('pontile', 'exostra', 'absit'),
#  ('rantipole', 'exostra', 'absit'),
#  ('sinople', 'exostra', 'absit'),
#  ('antipole', 'extra', 'absit'),
#  ('pinole', 'extra', 'absit'),
#  ('pontile', 'extra', 'absit'),
#  ('rantipole', 'extra', 'absit'),
#  ('sinople', 'extra', 'absit'),
#  ('noxal', 'lepra', 'absit'),
#  ('pearlin', 'noxa', 'absit'),
#  ('soleprint', 'toxa', 'absit'),
#  ('axile', 'etna', 'absorpt'),
#  ('oxalite', 'etna', 'absorpt'),
#  ('anile', 'exostra', 'absorpt'),
#  ('anisole', 'exostra', 'absorpt'),
#  ('antipole', 'exostra', 'absorpt'),
#  ('insolate', 'exostra', 'absorpt'),
#  ('insole', 'exostra', 'absorpt'),
#  ('pantile', 'exostra', 'absorpt'),
#  ('pinole', 'exostra', 'absorpt'),
#  ('pontile', 'exostra', 'absorpt'),
#  ('rantipole', 'exostra', 'absorpt'),
#  ('sinople', 'exostra', 'absorpt'),
#  ('anile', 'extra', 'absorpt'),
#  ('anisole', 'extra', 'absorpt'),
#  ('antipole', 'extra', 'absorpt'),
#  ('insolate', 'extra', 'absorpt'),
#  ('insole', 'extra', 'absorpt'),
#  ('pantile', 'extra', 'absorpt'),
#  ('pinole', 'extra', 'absorpt'),
#  ('pontile', 'extra', 'absorpt'),
#  ('rantipole', 'extra', 'absorpt'),
#  ('sinople', 'extra', 'absorpt'),
#  ('exorbital', 'lina', 'absorpt'),
#  ('extol', 'lina', 'absorpt'),
#  ('alexin', 'niepa', 'absorpt'),
#  ('alexin', 'nipa', 'absorpt'),
#  ('alexin', 'noxa', 'absorpt'),
#  ('aseptolin', 'noxa', 'absorpt'),
#  ('elastin', 'noxa', 'absorpt'),
#  ('elsin', 'noxa', 'absorpt'),
#  ('ileon', 'noxa', 'absorpt'),
#  ('olein', 'noxa', 'absorpt'),
#  ('pearlin', 'noxa', 'absorpt'),
#  ('plastein', 'noxa', 'absorpt'),
#  ('lino', 'oxea', 'absorpt'),
#  ('inlet', 'toxa', 'absorpt'),
#  ('onliest', 'toxa', 'absorpt'),
#  ('soleprint', 'toxa', 'absorpt'),
#  ('polaxis', 'strobila', 'aeon'),
#  ('praxis', 'strobila', 'aeon'),
#  ('protaxis', 'strobila', 'aeon'),
#  ('exorbital', 'lepa', 'aeonist'),
#  ('exorbital', 'lepra', 'aeonist'),
#  ('exorbital', 'lipa', 'aeonist'),
#  ('polaxis', 'strobila', 'aeonist'),
#  ('praxis', 'strobila', 'aeonist'),
#  ('protaxis', 'strobila', 'aeonist'),
#  ('binate', 'exostra', 'alepot'),
#  ('bonxie', 'exostra', 'alepot'),
#  ('inbe', 'exostra', 'alepot'),
#  ('sorbin', 'noxa', 'alepot'),
#  ('bisext', 'trona', 'alepot'),
#  ('probate', 'exostra', 'alexin'),
#  ('probe', 'exostra', 'alexin'),
#  ('soprani', 'ibota', 'alexin'),
#  ('apostil', 'libra', 'alexin'),
#  ('aseptol', 'libra', 'alexin'),
#  ('petrosal', 'libra', 'alexin'),
#  ('pistol', 'libra', 'alexin'),
#  ('postal', 'libra', 'alexin'),
#  ('postil', 'libra', 'alexin'),
#  ('strop', 'peba', 'alexin'),
#  ('bap', 'petrosa', 'alexin'),
#  ('beslap', 'petrosa', 'alexin'),
#  ('betrap', 'petrosa', 'alexin'),
#  ('bop', 'petrosa', 'alexin'),
#  ('beslap', 'porta', 'alexin'),
#  ('beslap', 'protea', 'alexin'),
#  ('baris', 'stopa', 'alexin'),
#  ('rabies', 'stopa', 'alexin'),
#  ('pobs', 'stra', 'alexin'),
#  ('aliptes', 'strobila', 'alexin'),
#  ('epos', 'strobila', 'alexin'),
#  ('panties', 'strobila', 'alexin'),
#  ('pants', 'strobila', 'alexin'),
#  ('paries', 'strobila', 'alexin'),
#  ('parotis', 'strobila', 'alexin'),
#  ('pelanos', 'strobila', 'alexin'),
#  ('pes', 'strobila', 'alexin'),
#  ('pietas', 'strobila', 'alexin'),
#  ('piles', 'strobila', 'alexin'),
#  ('plebs', 'strobila', 'alexin'),
#  ('plies', 'strobila', 'alexin'),
#  ('pobs', 'strobila', 'alexin'),
#  ('polaxis', 'strobila', 'alexin'),
#  ('polis', 'strobila', 'alexin'),
#  ('pontes', 'strobila', 'alexin'),
#  ('praxis', 'strobila', 'alexin'),
#  ('protaxis', 'strobila', 'alexin'),
#  ('ropes', 'strobila', 'alexin'),
#  ('talipes', 'strobila', 'alexin'),
#  ('tapis', 'strobila', 'alexin'),
#  ('trapes', 'strobila', 'alexin'),
#  ('tripos', 'strobila', 'alexin'),
#  ('absorpt', 'tea', 'alexin'),
#  ('barpost', 'tea', 'alexin'),
#  ('absorpt', 'tinosa', 'alexin'),
#  ('barpost', 'tinosa', 'alexin'),
#  ('bepart', 'tinosa', 'alexin'),
#  ('probant', 'tinosa', 'alexin'),
#  ('absorpt', 'tobira', 'alexin'),
#  ('alpist', 'tobira', 'alexin'),
#  ('barpost', 'tobira', 'alexin'),
#  ('parolist', 'tobira', 'alexin'),
#  ('past', 'tobira', 'alexin'),
#  ('pest', 'tobira', 'alexin'),
#  ('pist', 'tobira', 'alexin'),
#  ('pleonast', 'tobira', 'alexin'),
#  ('posit', 'tobira', 'alexin'),
#  ('post', 'tobira', 'alexin'),
#  ('priest', 'tobira', 'alexin'),
#  ('rapist', 'tobira', 'alexin'),
#  ('ripost', 'tobira', 'alexin'),
#  ('seaport', 'tobira', 'alexin'),
#  ('sept', 'tobira', 'alexin'),
#  ('slept', 'tobira', 'alexin'),
#  ('soleprint', 'tobira', 'alexin'),
#  ('absorpt', 'tora', 'alexin'),
#  ('barpost', 'tora', 'alexin'),
#  ('absorpt', 'toxa', 'alexin'),
#  ('barpost', 'toxa', 'alexin'),
#  ('absorpt', 'tra', 'alexin'),
#  ('barpost', 'tra', 'alexin'),
#  ('absorpt', 'trona', 'alexin'),
#  ('barpost', 'trona', 'alexin'),
#  ('probate', 'exostra', 'alin'),
#  ('probe', 'exostra', 'alin'),
#  ('binate', 'exostra', 'aliptes'),
#  ('bonxie', 'exostra', 'aliptes'),
#  ('branle', 'exostra', 'aliptes'),
#  ('bransle', 'exostra', 'aliptes'),
#  ('inbe', 'exostra', 'aliptes'),
#  ('bonxie', 'extra', 'aliptes'),
#  ('noxal', 'libra', 'aliptes'),
#  ('exorbital', 'lina', 'aliptes'),
#  ('abortin', 'noxa', 'aliptes'),
#  ('abrin', 'noxa', 'aliptes'),
#  ('atebrin', 'noxa', 'aliptes'),
#  ('baron', 'noxa', 'aliptes'),
#  ('barton', 'noxa', 'aliptes'),
#  ('bran', 'noxa', 'aliptes'),
#  ('brin', 'noxa', 'aliptes'),
#  ('brotan', 'noxa', 'aliptes'),
#  ('robin', 'noxa', 'aliptes'),
#  ('sorbin', 'noxa', 'aliptes'),
#  ('taborin', 'noxa', 'aliptes'),
#  ('brant', 'toxa', 'aliptes'),
#  ('probant', 'toxa', 'aliptes'),
#  ('bisext', 'trona', 'aliptes'),
#  ('probate', 'exostra', 'alison'),
#  ('probe', 'exostra', 'alison'),
#  ('probate', 'extra', 'alison'),
#  ('probe', 'extra', 'alison'),
#  ('exorbital', 'lepa', 'alison'),
#  ('exorbital', 'lepra', 'alison'),
#  ('exorbital', 'lipa', 'alison'),
#  ('bepart', 'toxa', 'alison'),
#  ('binate', 'exostra', 'alop'),
#  ('bonxie', 'exostra', 'alop'),
#  ('inbe', 'exostra', 'alop'),
#  ('bisext', 'trona', 'alop'),
#  ('binate', 'exostra', 'alp'),
#  ('bonxie', 'exostra', 'alp'),
#  ('inbe', 'exostra', 'alp'),
#  ('bisext', 'trona', 'alp'),
#  ('binate', 'exostra', 'alpist'),
#  ('bonxie', 'exostra', 'alpist'),
#  ('branle', 'exostra', 'alpist'),
#  ('bransle', 'exostra', 'alpist'),
#  ('inbe', 'exostra', 'alpist'),
#  ('bonxie', 'extra', 'alpist'),
#  ('exorbital', 'lina', 'alpist'),
#  ('atebrin', 'noxa', 'alpist'),
#  ('bisext', 'trona', 'alpist'),
#  ('probate', 'exostra', 'anil'),
#  ('probe', 'exostra', 'anil'),
#  ('probate', 'exostra', 'anile'),
#  ('probe', 'exostra', 'anile'),
#  ('polaxis', 'strobila', 'anile'),
#  ('praxis', 'strobila', 'anile'),
#  ('protaxis', 'strobila', 'anile'),
#  ('absorpt', 'toxa', 'anile'),
#  ('barpost', 'toxa', 'anile'),
#  ('exorbital', 'lepa', 'anis'),
#  ('exorbital', 'lepra', 'anis'),
#  ('exorbital', 'lipa', 'anis'),
#  ('exorbital', 'lepa', 'anise'),
#  ('exorbital', 'lepra', 'anise'),
#  ('exorbital', 'lipa', 'anise'),
#  ('polaxis', 'strobila', 'anise'),
#  ('praxis', 'strobila', 'anise'),
#  ('protaxis', 'strobila', 'anise'),
#  ('probate', 'exostra', 'anisole'),
#  ('probe', 'exostra', 'anisole'),
#  ('probate', 'extra', 'anisole'),
#  ('probe', 'extra', 'anisole'),
#  ('exorbital', 'lepa', 'anisole'),
#  ('exorbital', 'lepra', 'anisole'),
#  ('exorbital', 'lipa', 'anisole'),
#  ('polaxis', 'strobila', 'anisole'),
#  ('praxis', 'strobila', 'anisole'),
#  ('protaxis', 'strobila', 'anisole'),
#  ('absorpt', 'toxa', 'anisole'),
#  ('barpost', 'toxa', 'anisole'),
#  ('bepart', 'toxa', 'anisole'),
#  ('probant', 'toxa', 'anisole'),
#  ('polaxis', 'strobila', 'anole'),
#  ('praxis', 'strobila', 'anole'),
#  ('protaxis', 'strobila', 'anole'),
#  ('probate', 'exostra', 'anoli'),
#  ('probe', 'exostra', 'anoli'),
#  ('polaxis', 'strobila', 'ante'),
#  ('praxis', 'strobila', 'ante'),
#  ('protaxis', 'strobila', 'ante'),
#  ('exorbital', 'lepa', 'antes'),
#  ('exorbital', 'lepra', 'antes'),
#  ('exorbital', 'lipa', 'antes'),
#  ('polaxis', 'strobila', 'antes'),
#  ('praxis', 'strobila', 'antes'),
#  ('protaxis', 'strobila', 'antes'),
#  ('asbolite', 'exostra', 'antipole'),
#  ('bae', 'exostra', 'antipole'),
#  ('bale', 'exostra', 'antipole'),
#  ('barie', 'exostra', 'antipole'),
#  ('barile', 'exostra', 'antipole'),
#  ('barite', 'exostra', 'antipole'),
#  ('barse', 'exostra', 'antipole'),
#  ('base', 'exostra', 'antipole'),
#  ('basote', 'exostra', 'antipole'),
#  ('baste', 'exostra', 'antipole'),
#  ('bate', 'exostra', 'antipole'),
#  ('bile', 'exostra', 'antipole'),
#  ('binate', 'exostra', 'antipole'),
#  ('birle', 'exostra', 'antipole'),
#  ('birse', 'exostra', 'antipole'),
#  ('birsle', 'exostra', 'antipole'),
#  ('bite', 'exostra', 'antipole'),
#  ('bole', 'exostra', 'antipole'),
#  ('bonxie', 'exostra', 'antipole'),
#  ('borate', 'exostra', 'antipole'),
#  ('borlase', 'exostra', 'antipole'),
#  ('bose', 'exostra', 'antipole'),
#  ('bote', 'exostra', 'antipole'),
#  ('brae', 'exostra', 'antipole'),
#  ('branle', 'exostra', 'antipole'),
#  ('bransle', 'exostra', 'antipole'),
#  ('brose', 'exostra', 'antipole'),
#  ('inbe', 'exostra', 'antipole'),
#  ('laborite', 'exostra', 'antipole'),
#  ('labrose', 'exostra', 'antipole'),
#  ('latrobe', 'exostra', 'antipole'),
#  ('libate', 'exostra', 'antipole'),
#  ('librate', 'exostra', 'antipole'),
#  ('lobate', 'exostra', 'antipole'),
#  ('lobe', 'exostra', 'antipole'),
#  ('obe', 'exostra', 'antipole'),
#  ('orbitale', 'exostra', 'antipole'),
#  ('orbite', 'exostra', 'antipole'),
#  ('probate', 'exostra', 'antipole'),
#  ('probe', 'exostra', 'antipole'),
#  ('ribe', 'exostra', 'antipole'),
#  ('ribose', 'exostra', 'antipole'),
#  ('robe', 'exostra', 'antipole'),
#  ('sabe', 'exostra', 'antipole'),
#  ('sobralite', 'exostra', 'antipole'),
#  ('sorbate', 'exostra', 'antipole'),
#  ('sorbile', 'exostra', 'antipole'),
#  ('sorbite', 'exostra', 'antipole'),
#  ('stabile', 'exostra', 'antipole'),
#  ('strobilae', 'exostra', 'antipole'),
#  ('strobile', 'exostra', 'antipole'),
#  ('tobe', 'exostra', 'antipole'),
#  ('tribase', 'exostra', 'antipole'),
#  ('tribe', 'exostra', 'antipole'),
#  ('trilabe', 'exostra', 'antipole'),
#  ('trilobe', 'exostra', 'antipole'),
#  ('asbolite', 'extra', 'antipole'),
#  ('barse', 'extra', 'antipole'),
#  ('base', 'extra', 'antipole'),
#  ('basote', 'extra', 'antipole'),
#  ('baste', 'extra', 'antipole'),
#  ('birse', 'extra', 'antipole'),
#  ('birsle', 'extra', 'antipole'),
#  ('borlase', 'extra', 'antipole'),
#  ('bose', 'extra', 'antipole'),
#  ('bransle', 'extra', 'antipole'),
#  ('brose', 'extra', 'antipole'),
#  ('labrose', 'extra', 'antipole'),
#  ('ribose', 'extra', 'antipole'),
#  ('sabe', 'extra', 'antipole'),
#  ('sobralite', 'extra', 'antipole'),
#  ('sorbate', 'extra', 'antipole'),
#  ('sorbile', 'extra', 'antipole'),
#  ('sorbite', 'extra', 'antipole'),
#  ('stabile', 'extra', 'antipole'),
#  ('strobilae', 'extra', 'antipole'),
#  ('strobile', 'extra', 'antipole'),
#  ('tribase', 'extra', 'antipole'),
#  ('sorbin', 'noxa', 'antipole'),
#  ('bistro', 'oxea', 'antipole'),
#  ('axes', 'strobila', 'antipole'),
#  ('axis', 'strobila', 'antipole'),
#  ('polaxis', 'strobila', 'antipole'),
#  ('praxis', 'strobila', 'antipole'),
#  ('protaxis', 'strobila', 'antipole'),
#  ('taxis', 'strobila', 'antipole'),
#  ('bisext', 'tobira', 'antipole'),
#  ('exist', 'tobira', 'antipole'),
#  ('laxist', 'tobira', 'antipole'),
#  ('sext', 'tobira', 'antipole'),
#  ('bisext', 'tora', 'antipole'),
#  ('absorpt', 'toxa', 'antipole'),
#  ('barpost', 'toxa', 'antipole'),
#  ('laborist', 'toxa', 'antipole'),
#  ('bisext', 'tra', 'antipole'),
#  ('bisext', 'trona', 'antipole'),
#  ('asbolite', 'exostra', 'apeiron'),
#  ('bale', 'exostra', 'apeiron'),
#  ('barile', 'exostra', 'apeiron'),
#  ('bile', 'exostra', 'apeiron'),
#  ('birle', 'exostra', 'apeiron'),
#  ('birsle', 'exostra', 'apeiron'),
#  ('bole', 'exostra', 'apeiron'),
#  ('borlase', 'exostra', 'apeiron'),
#  ('branle', 'exostra', 'apeiron'),
#  ('bransle', 'exostra', 'apeiron'),
#  ('laborite', 'exostra', 'apeiron'),
#  ('labrose', 'exostra', 'apeiron'),
#  ('latrobe', 'exostra', 'apeiron'),
#  ('libate', 'exostra', 'apeiron'),
#  ('librate', 'exostra', 'apeiron'),
#  ('lobate', 'exostra', 'apeiron'),
#  ('lobe', 'exostra', 'apeiron'),
#  ('orbitale', 'exostra', 'apeiron'),
#  ('sobralite', 'exostra', 'apeiron'),
#  ('sorbile', 'exostra', 'apeiron'),
#  ('stabile', 'exostra', 'apeiron'),
#  ('strobilae', 'exostra', 'apeiron'),
#  ('strobile', 'exostra', 'apeiron'),
#  ('trilabe', 'exostra', 'apeiron'),
#  ('trilobe', 'exostra', 'apeiron'),
#  ('asbolite', 'extra', 'apeiron'),
#  ('birsle', 'extra', 'apeiron'),
#  ('borlase', 'extra', 'apeiron'),
#  ('bransle', 'extra', 'apeiron'),
#  ('labrose', 'extra', 'apeiron'),
#  ('sobralite', 'extra', 'apeiron'),
#  ('sorbile', 'extra', 'apeiron'),
#  ('stabile', 'extra', 'apeiron'),
#  ('strobilae', 'extra', 'apeiron'),
#  ('strobile', 'extra', 'apeiron'),
#  ('axes', 'strobila', 'apeiron'),
#  ('axis', 'strobila', 'apeiron'),
#  ('polaxis', 'strobila', 'apeiron'),
#  ('praxis', 'strobila', 'apeiron'),
#  ('protaxis', 'strobila', 'apeiron'),
#  ('taxis', 'strobila', 'apeiron'),
#  ('laxist', 'tobira', 'apeiron'),
#  ('laborist', 'toxa', 'apeiron'),
#  ('sobralite', 'etna', 'apex'),
#  ('sorbile', 'etna', 'apex'),
#  ('strobilae', 'etna', 'apex'),
#  ('strobile', 'etna', 'apex'),
#  ('nostril', 'libra', 'apex'),
#  ('tonsil', 'libra', 'apex'),
#  ('anis', 'strobila', 'apex'),
#  ('antes', 'strobila', 'apex'),
#  ('nabs', 'strobila', 'apex'),
#  ('nates', 'strobila', 'apex'),
#  ('nibs', 'strobila', 'apex'),
#  ('nirles', 'strobila', 'apex'),
#  ('nobs', 'strobila', 'apex'),
#  ('ons', 'strobila', 'apex'),
#  ('panties', 'strobila', 'apex'),
#  ('pants', 'strobila', 'apex'),
#  ('pelanos', 'strobila', 'apex'),
#  ('pontes', 'strobila', 'apex'),
#  ('laborist', 'tinosa', 'apex'),
#  ('onliest', 'tobira', 'apex'),
#  ('pleonast', 'tobira', 'apex'),
#  ('slant', 'tobira', 'apex'),
#  ('soleprint', 'tobira', 'apex'),
#  ('laborist', 'trona', 'apex'),
#  ('binate', 'exostra', 'aplite'),
#  ('bonxie', 'exostra', 'aplite'),
#  ('branle', 'exostra', 'aplite'),
#  ('bransle', 'exostra', 'aplite'),
#  ('inbe', 'exostra', 'aplite'),
#  ('sorbin', 'noxa', 'aplite'),
#  ('bisext', 'trona', 'aplite'),
#  ('binate', 'exostra', 'apostil'),
#  ('bonxie', 'exostra', 'apostil'),
#  ('branle', 'exostra', 'apostil'),
#  ('bransle', 'exostra', 'apostil'),
#  ('inbe', 'exostra', 'apostil'),
#  ('binate', 'extra', 'apostil'),
#  ('bonxie', 'extra', 'apostil'),
#  ('branle', 'extra', 'apostil'),
#  ('bransle', 'extra', 'apostil'),
#  ('inbe', 'extra', 'apostil'),
#  ('exorbital', 'lina', 'apostil'),
#  ('atebrin', 'noxa', 'apostil'),
#  ('bisext', 'trona', 'apostil'),
#  ('asbolite', 'exostra', 'apron'),
#  ('barile', 'exostra', 'apron'),
#  ('bile', 'exostra', 'apron'),
#  ('birle', 'exostra', 'apron'),
#  ('birsle', 'exostra', 'apron'),
#  ('laborite', 'exostra', 'apron'),
#  ('libate', 'exostra', 'apron'),
#  ('librate', 'exostra', 'apron'),
#  ('orbitale', 'exostra', 'apron'),
#  ('sobralite', 'exostra', 'apron'),
#  ('sorbile', 'exostra', 'apron'),
#  ('stabile', 'exostra', 'apron'),
#  ('strobilae', 'exostra', 'apron'),
#  ('strobile', 'exostra', 'apron'),
#  ('trilabe', 'exostra', 'apron'),
#  ('trilobe', 'exostra', 'apron'),
#  ('asbolite', 'extra', 'apron'),
#  ('birsle', 'extra', 'apron'),
#  ('sobralite', 'extra', 'apron'),
#  ('sorbile', 'extra', 'apron'),
#  ('stabile', 'extra', 'apron'),
#  ('strobilae', 'extra', 'apron'),
#  ('strobile', 'extra', 'apron'),
#  ('axes', 'strobila', 'apron'),
#  ('exorbital', 'lepa', 'arsino'),
#  ('exorbital', 'lepra', 'arsino'),
#  ('exorbital', 'lipa', 'arsino'),
#  ('exorbital', 'lepa', 'arson'),
#  ('exorbital', 'lepra', 'arson'),
#  ('exorbital', 'lipa', 'arson'),
#  ('exorbital', 'lepa', 'arsonite'),
#  ('exorbital', 'lepra', 'arsonite'),
#  ('exorbital', 'lipa', 'arsonite'),
#  ('oxlip', 'peba', 'arsonite'),
#  ('polaxis', 'strobila', 'arsonite'),
#  ('praxis', 'strobila', 'arsonite'),
#  ('protaxis', 'strobila', 'arsonite'),
#  ('panties', 'strobila', 'arx'),
#  ('pelanos', 'strobila', 'arx'),
#  ('pontes', 'strobila', 'arx'),
#  ('pleonast', 'tobira', 'arx'),
#  ('soleprint', 'tobira', 'arx'),
#  ('antipole', 'exostra', 'asbolin'),
#  ('ape', 'exostra', 'asbolin'),
#  ('aplite', 'exostra', 'asbolin'),
#  ('aslope', 'exostra', 'asbolin'),
#  ('lipase', 'exostra', 'asbolin'),
#  ('lope', 'exostra', 'asbolin'),
#  ('nape', 'exostra', 'asbolin'),
#  ('nope', 'exostra', 'asbolin'),
#  ('olpe', 'exostra', 'asbolin'),
#  ('ope', 'exostra', 'asbolin'),
#  ('pale', 'exostra', 'asbolin'),
#  ('panse', 'exostra', 'asbolin'),
#  ('pantie', 'exostra', 'asbolin'),
#  ('pantile', 'exostra', 'asbolin'),
#  ('parle', 'exostra', 'asbolin'),
#  ('parole', 'exostra', 'asbolin'),
#  ('parse', 'exostra', 'asbolin'),
#  ('partile', 'exostra', 'asbolin'),
#  ('paste', 'exostra', 'asbolin'),
#  ('pastile', 'exostra', 'asbolin'),
#  ('pate', 'exostra', 'asbolin'),
#  ('pie', 'exostra', 'asbolin'),
#  ('pile', 'exostra', 'asbolin'),
#  ('pilose', 'exostra', 'asbolin'),
#  ('pinole', 'exostra', 'asbolin'),
#  ('pinte', 'exostra', 'asbolin'),
#  ('pirate', 'exostra', 'asbolin'),
#  ('pise', 'exostra', 'asbolin'),
#  ('pistole', 'exostra', 'asbolin'),
#  ('plate', 'exostra', 'asbolin'),
#  ('plote', 'exostra', 'asbolin'),
#  ('poe', 'exostra', 'asbolin'),
#  ('pole', 'exostra', 'asbolin'),
#  ('polite', 'exostra', 'asbolin'),
#  ('pontile', 'exostra', 'asbolin'),
#  ('porite', 'exostra', 'asbolin'),
#  ('pose', 'exostra', 'asbolin'),
#  ('pote', 'exostra', 'asbolin'),
#  ('prase', 'exostra', 'asbolin'),
#  ('prate', 'exostra', 'asbolin'),
#  ('probate', 'exostra', 'asbolin'),
#  ('probe', 'exostra', 'asbolin'),
#  ('prolate', 'exostra', 'asbolin'),
#  ('pronate', 'exostra', 'asbolin'),
#  ('prose', 'exostra', 'asbolin'),
#  ('prote', 'exostra', 'asbolin'),
#  ('rantipole', 'exostra', 'asbolin'),
#  ('rape', 'exostra', 'asbolin'),
#  ('ripe', 'exostra', 'asbolin'),
#  ('riposte', 'exostra', 'asbolin'),
#  ('rope', 'exostra', 'asbolin'),
#  ('saple', 'exostra', 'asbolin'),
#  ('saponite', 'exostra', 'asbolin'),
#  ('sapote', 'exostra', 'asbolin'),
#  ('saprolite', 'exostra', 'asbolin'),
#  ('sinople', 'exostra', 'asbolin'),
#  ('sipe', 'exostra', 'asbolin'),
#  ('sirple', 'exostra', 'asbolin'),
#  ('slape', 'exostra', 'asbolin'),
#  ('slipe', 'exostra', 'asbolin'),
#  ('slope', 'exostra', 'asbolin'),
#  ('snape', 'exostra', 'asbolin'),
#  ('snipe', 'exostra', 'asbolin'),
#  ('sope', 'exostra', 'asbolin'),
#  ('sopite', 'exostra', 'asbolin'),
#  ('staple', 'exostra', 'asbolin'),
#  ('stipe', 'exostra', 'asbolin'),
#  ('stope', 'exostra', 'asbolin'),
#  ('stripe', 'exostra', 'asbolin'),
#  ('tape', 'exostra', 'asbolin'),
#  ('tipe', 'exostra', 'asbolin'),
#  ('tiple', 'exostra', 'asbolin'),
#  ('tope', 'exostra', 'asbolin'),
#  ('tripe', 'exostra', 'asbolin'),
#  ('triple', 'exostra', 'asbolin'),
#  ('trope', 'exostra', 'asbolin'),
#  ('antipole', 'extra', 'asbolin'),
#  ('ape', 'extra', 'asbolin'),
#  ('aplite', 'extra', 'asbolin'),
#  ('aslope', 'extra', 'asbolin'),
#  ('lipase', 'extra', 'asbolin'),
#  ('lope', 'extra', 'asbolin'),
#  ('nape', 'extra', 'asbolin'),
#  ('nope', 'extra', 'asbolin'),
#  ('olpe', 'extra', 'asbolin'),
#  ('ope', 'extra', 'asbolin'),
#  ('pale', 'extra', 'asbolin'),
#  ('panse', 'extra', 'asbolin'),
#  ('pantie', 'extra', 'asbolin'),
#  ('pantile', 'extra', 'asbolin'),
#  ('parle', 'extra', 'asbolin'),
#  ('parole', 'extra', 'asbolin'),
#  ('parse', 'extra', 'asbolin'),
#  ('partile', 'extra', 'asbolin'),
#  ('paste', 'extra', 'asbolin'),
#  ('pastile', 'extra', 'asbolin'),
#  ('pate', 'extra', 'asbolin'),
#  ('pie', 'extra', 'asbolin'),
#  ('pile', 'extra', 'asbolin'),
#  ('pilose', 'extra', 'asbolin'),
#  ('pinole', 'extra', 'asbolin'),
#  ('pinte', 'extra', 'asbolin'),
#  ('pirate', 'extra', 'asbolin'),
#  ('pise', 'extra', 'asbolin'),
#  ('pistole', 'extra', 'asbolin'),
#  ('plate', 'extra', 'asbolin'),
#  ('plote', 'extra', 'asbolin'),
#  ('poe', 'extra', 'asbolin'),
#  ('pole', 'extra', 'asbolin'),
#  ('polite', 'extra', 'asbolin'),
#  ('pontile', 'extra', 'asbolin'),
#  ('porite', 'extra', 'asbolin'),
#  ('pose', 'extra', 'asbolin'),
#  ('pote', 'extra', 'asbolin'),
#  ('prase', 'extra', 'asbolin'),
#  ('prate', 'extra', 'asbolin'),
#  ('probate', 'extra', 'asbolin'),
#  ('probe', 'extra', 'asbolin'),
#  ('prolate', 'extra', 'asbolin'),
#  ('pronate', 'extra', 'asbolin'),
#  ('prose', 'extra', 'asbolin'),
#  ('prote', 'extra', 'asbolin'),
#  ('rantipole', 'extra', 'asbolin'),
#  ('rape', 'extra', 'asbolin'),
#  ('ripe', 'extra', 'asbolin'),
#  ('riposte', 'extra', 'asbolin'),
#  ('rope', 'extra', 'asbolin'),
#  ('saple', 'extra', 'asbolin'),
#  ('saponite', 'extra', 'asbolin'),
#  ('sapote', 'extra', 'asbolin'),
#  ('saprolite', 'extra', 'asbolin'),
#  ('sinople', 'extra', 'asbolin'),
#  ('sipe', 'extra', 'asbolin'),
#  ('sirple', 'extra', 'asbolin'),
#  ('slape', 'extra', 'asbolin'),
#  ('slipe', 'extra', 'asbolin'),
#  ('slope', 'extra', 'asbolin'),
#  ('snape', 'extra', 'asbolin'),
#  ('snipe', 'extra', 'asbolin'),
#  ('sope', 'extra', 'asbolin'),
#  ('sopite', 'extra', 'asbolin'),
#  ('staple', 'extra', 'asbolin'),
#  ('stipe', 'extra', 'asbolin'),
#  ('stope', 'extra', 'asbolin'),
#  ('stripe', 'extra', 'asbolin'),
#  ('tape', 'extra', 'asbolin'),
#  ('tipe', 'extra', 'asbolin'),
#  ('tiple', 'extra', 'asbolin'),
#  ('tope', 'extra', 'asbolin'),
#  ('tripe', 'extra', 'asbolin'),
#  ('triple', 'extra', 'asbolin'),
#  ('trope', 'extra', 'asbolin'),
#  ('exorbital', 'lepa', 'asbolin'),
#  ('exorbital', 'lepra', 'asbolin'),
#  ('extol', 'lepra', 'asbolin'),
#  ('exorbital', 'lipa', 'asbolin'),
#  ('protean', 'noxa', 'asbolin'),
#  ('protein', 'noxa', 'asbolin'),
#  ('parto', 'oxea', 'asbolin'),
#  ('oxlip', 'petrosa', 'asbolin'),
#  ('oxlip', 'protea', 'asbolin'),
#  ('sextar', 'ripa', 'asbolin'),
#  ('plexor', 'rita', 'asbolin'),
#  ('sexipolar', 'rita', 'asbolin'),
#  ('plexor', 'rota', 'asbolin'),
#  ('sexipolar', 'rota', 'asbolin'),
#  ('protaxis', 'sea', 'asbolin'),
#  ('praxis', 'septa', 'asbolin'),
#  ('protaxis', 'septa', 'asbolin'),
#  ('praxis', 'seta', 'asbolin'),
#  ('protaxis', 'seta', 'asbolin'),
#  ('protaxis', 'sirpea', 'asbolin'),
#  ('taxis', 'sirpea', 'asbolin'),
#  ('protaxis', 'solea', 'asbolin'),
#  ('praxis', 'stela', 'asbolin'),
#  ('protaxis', 'stela', 'asbolin'),
#  ('bepart', 'toxa', 'asbolin'),
#  ('peart', 'toxa', 'asbolin'),
#  ('priest', 'toxa', 'asbolin'),
#  ('seaport', 'toxa', 'asbolin'),
#  ('soleprint', 'toxa', 'asbolin'),
#  ('antipole', 'exostra', 'asbolite'),
#  ('nape', 'exostra', 'asbolite'),
#  ('nope', 'exostra', 'asbolite'),
#  ('panse', 'exostra', 'asbolite'),
#  ('pantie', 'exostra', 'asbolite'),
#  ('pantile', 'exostra', 'asbolite'),
#  ('pinole', 'exostra', 'asbolite'),
#  ('pinte', 'exostra', 'asbolite'),
#  ('pontile', 'exostra', 'asbolite'),
#  ('pronate', 'exostra', 'asbolite'),
#  ('rantipole', 'exostra', 'asbolite'),
#  ('saponite', 'exostra', 'asbolite'),
#  ('sinople', 'exostra', 'asbolite'),
#  ('snape', 'exostra', 'asbolite'),
#  ('snipe', 'exostra', 'asbolite'),
#  ('antipole', 'extra', 'asbolite'),
#  ('nape', 'extra', 'asbolite'),
#  ('nope', 'extra', 'asbolite'),
#  ('panse', 'extra', 'asbolite'),
#  ('pantie', 'extra', 'asbolite'),
#  ('pantile', 'extra', 'asbolite'),
#  ('pinole', 'extra', 'asbolite'),
#  ('pinte', 'extra', 'asbolite'),
#  ('pontile', 'extra', 'asbolite'),
#  ('pronate', 'extra', 'asbolite'),
#  ('rantipole', 'extra', 'asbolite'),
#  ('saponite', 'extra', 'asbolite'),
#  ('sinople', 'extra', 'asbolite'),
#  ('snape', 'extra', 'asbolite'),
#  ('snipe', 'extra', 'asbolite'),
#  ('noxal', 'lepra', 'asbolite'),
#  ('apeiron', 'noxa', 'asbolite'),
#  ('apron', 'noxa', 'asbolite'),
#  ('parison', 'noxa', 'asbolite'),
#  ('parson', 'noxa', 'asbolite'),
#  ('patrin', 'noxa', 'asbolite'),
#  ('patron', 'noxa', 'asbolite'),
#  ('pearlin', 'noxa', 'asbolite'),
#  ('plastron', 'noxa', 'asbolite'),
#  ('prison', 'noxa', 'asbolite'),
#  ('prolan', 'noxa', 'asbolite'),
#  ('protean', 'noxa', 'asbolite'),
#  ('protein', 'noxa', 'asbolite'),
#  ('tarpon', 'noxa', 'asbolite'),
#  ('praxis', 'sina', 'asbolite'),
#  ('protaxis', 'sina', 'asbolite'),
#  ('inport', 'toxa', 'asbolite'),
#  ('print', 'toxa', 'asbolite'),
#  ('probant', 'toxa', 'asbolite'),
#  ('soleprint', 'toxa', 'asbolite'),
#  ('binate', 'exostra', 'aseptol'),
#  ('bonxie', 'exostra', 'aseptol'),
#  ('inbe', 'exostra', 'aseptol'),
#  ('binate', 'extra', 'aseptol'),
#  ('bonxie', 'extra', 'aseptol'),
#  ('inbe', 'extra', 'aseptol'),
#  ('noxal', 'libra', 'aseptol'),
#  ('exorbital', 'lina', 'aseptol'),
#  ('abortin', 'noxa', 'aseptol'),
#  ('abrin', 'noxa', 'aseptol'),
#  ('atebrin', 'noxa', 'aseptol'),
#  ('brin', 'noxa', 'aseptol'),
#  ('robin', 'noxa', 'aseptol'),
#  ('sorbin', 'noxa', 'aseptol'),
#  ('taborin', 'noxa', 'aseptol'),
#  ('bisext', 'trona', 'aseptol'),
#  ('asbolite', 'exostra', 'aseptolin'),
#  ('bae', 'exostra', 'aseptolin'),
#  ('bale', 'exostra', 'aseptolin'),
#  ('barie', 'exostra', 'aseptolin'),
#  ('barile', 'exostra', 'aseptolin'),
#  ('barite', 'exostra', 'aseptolin'),
#  ('barse', 'exostra', 'aseptolin'),
#  ('base', 'exostra', 'aseptolin'),
#  ('basote', 'exostra', 'aseptolin'),
#  ('baste', 'exostra', 'aseptolin'),
#  ...]

# %%
# puzzle = ['omt',
#           'uri',
#           'haf',
#           'lpg']
# puzzle_set = set(''.join(puzzle))

# words_possible = [word for word in words if not (set(word) - puzzle_set)]   
# alphabet = 'abcdefghijklmnopqrstuvwxyz'

# not_in_puzzle = set(alphabet) -  puzzle_set

# 132 ms
# %timeit words_possible = [word for word in words if not set(word) & not_in_puzzle] 

# 350 ms
# %timeit words_possible = [word for word in words if all([letter in ''.join(puzzle) for letter in word])]
